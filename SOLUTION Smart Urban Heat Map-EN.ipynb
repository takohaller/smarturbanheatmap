# %% [markdown]
# # Simple Example of IoT Programming for the Smart City
#
# This example shows how temperature and humidity data from weather stations in the Bern region can be queried and visualised using simple Python code. This example was developed as part of the __[Smart Urban Heat Map Bern](https://smart-urban-heat-map.ch/)__ project.
#
# It uses a **Web-API** that was defined by [MeteoTest](https://meteotest.ch/en/company/about-us), a Swiss private company that develops and sells data driven services and products in the areas of weather, climate and the environment. It is simple to use, but doesn't conform to any standards like [SensorThings](https://www.ogc.org/standard/sensorthings/) defined by the [Open Geospatial Consortium](https://www.ogc.org/).
#
# API documentation: https://meteotest.github.io/urban-heat-API-docs/Swagger/.

# %% [markdown]
# ## Part 1 - Loading and Displaying Current Data

# %% [markdown]
# ### Step 1: Importing the required Python libraries

# %%
import io # for working with streams (like strings)
import requests # for making standard HTTP requests
import pandas as pd # for storing and manipulating data
import geopandas as gpd # for storing and manipulating geographic data
import folium # for creating maps
import branca # for using colorscales in Folium
import json # for data handling

# %% [markdown]
# ### Step 2: Query list of all weather stations

# %%
# Define the URL
url = "https://smart-urban-heat-map.ch/api/1.0/stations"

# Make the GET request
response = requests.get(url)

# Display the result
print(response.text)
# Out:
# {"type": "FeatureCollection", "features": [{"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.44165, 46.96523]}, "properties": {"stationId": "1040CBFEFFE70FFE", "name": "Viererfeld 4 (Strasse Nord)", "dateObserved": "2024-05-28T05:56:37Z", "temperature": 11.165027, "relativeHumidity": 96.40711}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.30673, 47.089134]}, "properties": {"stationId": "4DE350FEFF6E959E", "name": "Industriering Nord", "dateObserved": "2024-05-28T05:56:13Z", "temperature": 12.556268, "relativeHumidity": 75.73876}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43639, 46.94734]}, "properties": {"stationId": "3940CBFEFFE70FFE", "name": "Laupenstrasse", "dateObserved": "2024-05-28T05:56:12Z", "temperature": 11.8726635, "relativeHumidity": 89.04845}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.438822, 46.977913]}, "properties": {"stationId": "57D550FEFF6E959E", "name": "Bremgarten Ecke Lindenstrasse / Ritterstrasse Laterne", "dateObserved": "2024-05-28T05:56:12Z", "temperature": 11.429389, "relativeHumidity": 90.849014}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43843, 46.94728]}, "properties": {"stationId": "FE3FCBFEFFE70FFE", "name": "Bubenbergplatz", "dateObserved": "2024-05-28T05:56:12Z", "temperature": 12.155718, "relativeHumidity": 86.49828}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.392484, 46.951385]}, "properties": {"stationId": "12E350FEFF6E959E", "name": "Bern Bethlehem Laterne", "dateObserved": "2024-05-28T05:56:11Z", "temperature": 12.532235, "relativeHumidity": 85.7277}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.470893, 46.90922]}, "properties": {"stationId": "11E350FEFF6E959E", "name": "Kehrsatz Zentrum Laterne", "dateObserved": "2024-05-28T05:56:08Z", "temperature": 11.154345, "relativeHumidity": 87.02472}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.497151, 46.975468]}, "properties": {"stationId": "C9EA50FEFF6E959E", "name": "Bolligen Sternenkreisel Laterne", "dateObserved": "2024-05-28T05:56:03Z", "temperature": 11.221104, "relativeHumidity": 86.13779}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43971, 46.91833]}, "properties": {"stationId": "190551FEFF6E959E", "name": "Gurten Kulm 3", "dateObserved": "2024-05-28T05:56:01Z", "temperature": 11.317235, "relativeHumidity": 89.0885}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42128, 46.96512]}, "properties": {"stationId": "C03FCBFEFFE70FFE", "name": "Bremgartenwald", "dateObserved": "2024-05-28T05:55:50Z", "temperature": 10.606928, "relativeHumidity": 97.816666}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43141, 46.94067]}, "properties": {"stationId": "3A0551FEFF6E959E", "name": "Eigerplatz", "dateObserved": "2024-05-28T05:55:48Z", "temperature": 11.717784, "relativeHumidity": 90.47517}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.46247, 46.968]}, "properties": {"stationId": "ECC450FEFF6E959E", "name": "Wankdorf ESP 2", "dateObserved": "2024-05-28T05:55:44Z", "temperature": 11.402685, "relativeHumidity": 92.71633}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.46244, 46.96798]}, "properties": {"stationId": "1E0551FEFF6E959E", "name": "Wankdorf ESP", "dateObserved": "2024-05-28T05:55:36Z", "temperature": 11.586938, "relativeHumidity": 90.07843}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42713, 46.94479]}, "properties": {"stationId": "0940CBFEFFE70FFE", "name": "Kreuzung Brunnmatt-Schwarztorstrasse", "dateObserved": "2024-05-28T05:55:32Z", "temperature": 12.259861, "relativeHumidity": 87.793396}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.47194, 46.95553]}, "properties": {"stationId": "270551FEFF6E959E", "name": "Galgenfeld Industrie", "dateObserved": "2024-05-28T05:55:29Z", "temperatur ...

# %% [markdown]
# Reformatting for better readability:

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44165,
#           46.96523
#         ]
#       },
#       "properties": {
#         "stationId": "1040CBFEFFE70FFE",
#         "name": "Viererfeld 4 (Strasse Nord)",
#         "dateObserved": "2024-05-28T05:56:37Z",
#         "temperature": 11.165027,
#         "relativeHumidity": 96.40711
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.30673,
#           47.089134
#         ]
#       },
#       "properties": {
#         "stationId": "4DE350FEFF6E959E",
#         "name": "Industriering Nord",
#         "dateObserved": "2024-05-28T05:56:13Z",
#         "temperature": 12.556268,
#         "relativeHumidity": 75.73876
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43639,
#           46.94734
#         ]
#       },
#       "properties": {
#         "stationId": "3940CBFEFFE70FFE",
#         "name": "Laupenstrasse",
#         "dateObserved": "2024-05-28T05:56:12Z",
#         "temperature": 11.8726635,
#         "relativeHumidity": 89.04845
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.438822,
#           46.977913
#         ]
#       },
#       "properties": {
#         "stationId": "57D550FEFF6E959E",
#         "name": "Bremgarten Ecke Lindenstrasse / Ritterstrasse Laterne",
#         "dateObserved": "2024-05-28T05:56:12Z",
#         "temperature": 11.429389,
#         "relativeHumidity": 90.849014
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43843,
#           46.94728
#         ]
#       },
#       "properties": {
#         "stationId": "FE3FCBFEFFE70FFE",
#         "name": "Bubenbergplatz",
#         "dateObserved": "2024-05-28T05:56:12Z",
#         "temperature": 12.155718,
#         "relativeHumidity": 86.49828
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.392484,
#           46.951385
#         ]
#       },
#       "properties": {
#         "stationId": "12E350FEFF6E959E",
#         "name": "Bern Bethlehem Laterne",
#         "dateObserved": "2024-05-28T05:56:11Z",
#         "temperature": 12.532235,
#         "relativeHumidity": 85.7277
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.470893,
#           46.90922
#         ]
#       },
#       "properties": {
#         "stationId": "11E350FEFF6E959E",
#         "name": "Kehrsatz Zentrum Laterne",
#         "dateObserved": "2024-05-28T05:56:08Z",
#         "temperature": 11.154345,
#         "relativeHumidity": 87.02472
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.497151,
#           46.975468
#         ]
#       },
#       "properties": {
#         "stationId": "C9EA50FEFF6E959E",
#         "name": "Bolligen Sternenkreisel Laterne",
#         "dateObserved": "2024-05-28T05:56:03Z",
#         "temperature": 11.221104,
#         "relativeHumidity": 86.13779
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "190551FEFF6E959E",
#         "name": "Gurten Kulm 3",
#         "dateObserved": "2024-05-28T05:56:01Z",
#         "temperature": 11.317235,
#         "relativeHumidity": 89.0885
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42128,
#           46.96512
#         ]
#       },
#       "properties": {
#         "stationId": "C03FCBFEFFE70FFE",
#         "name": "Bremgartenwald",
#         "dateObserved": "2024-05-28T05:55:50Z",
#         "temperature": 10.606928,
#         "relativeHumidity": 97.816666
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43141,
#           46.94067
#         ]
#       },
#       "properties": {
#         "stationId": "3A0551FEFF6E959E",
#         "name": "Eigerplatz",
#         "dateObserved": "2024-05-28T05:55:48Z",
#         "temperature": 11.717784,
#         "relativeHumidity": 90.47517
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46247,
#           46.968
#         ]
#       },
#       "properties": {
#         "stationId": "ECC450FEFF6E959E",
#         "name": "Wankdorf ESP 2",
#         "dateObserved": "2024-05-28T05:55:44Z",
#         "temperature": 11.402685,
#         "relativeHumidity": 92.71633
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46244,
#           46.96798
#         ]
#       },
#       "properties": {
#         "stationId": "1E0551FEFF6E959E",
#         "name": "Wankdorf ESP",
#         "dateObserved": "2024-05-28T05:55:36Z",
#         "temperature": 11.586938,
#         "relativeHumidity": 90.07843
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42713,
#           46.94479
#         ]
#       },
#       "properties": {
#         "stationId": "0940CBFEFFE70FFE",
#         "name": "Kreuzung Brunnmatt-Schwarztorstrasse",
#         "dateObserved": "2024-05-28T05:55:32Z",
#         "temperature": 12.259861,
#         "relativeHumidity": 87.793396
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47194,
#           46.95553
#         ]
#       },
#       "properties": {
#         "stationId": "270551FEFF6E959E",
#         "name": "Galgenfeld Industrie",
#         "dateObserved": "2024-05-28T05:55:29Z",
#         "temperature": 11.146334,
#         "relativeHumidity": 95.318
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4602,
#           46.95188
#         ]
#       },
#       "properties": {
#         "stationId": "F5C450FEFF6E959E",
#         "name": "Rosengarten",
#         "dateObserved": "2024-05-28T05:55:08Z",
#         "temperature": 11.0048065,
#         "relativeHumidity": 96.233536
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44361,
#           46.94826
#         ]
#       },
#       "properties": {
#         "stationId": "1840CBFEFFE70FFE",
#         "name": "B\u00e4renplatz",
#         "dateObserved": "2024-05-28T05:55:02Z",
#         "temperature": 11.560235,
#         "relativeHumidity": 89.874344
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46407,
#           46.94714
#         ]
#       },
#       "properties": {
#         "stationId": "1C40CBFEFFE70FFE",
#         "name": "Obstberg, Wattenwylweg 32",
#         "dateObserved": "2024-05-28T05:54:45Z",
#         "temperature": 11.397345,
#         "relativeHumidity": 95.710915
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50376,
#           46.96681
#         ]
#       },
#       "properties": {
#         "stationId": "140551FEFF6E959E",
#         "name": "Umland Bolligen",
#         "dateObserved": "2024-05-28T05:54:41Z",
#         "temperature": 11.130312,
#         "relativeHumidity": 97.86435
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.39587,
#           46.94302
#         ]
#       },
#       "properties": {
#         "stationId": "0C0551FEFF6E959E",
#         "name": "B\u00fcmpliz St\u00f6ckacker",
#         "dateObserved": "2024-05-28T05:54:27Z",
#         "temperature": 11.918059,
#         "relativeHumidity": 89.229645
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44513,
#           46.95898
#         ]
#       },
#       "properties": {
#         "stationId": "EA3FCBFEFFE70FFE",
#         "name": "Lorraine, Steckweg 17",
#         "dateObserved": "2024-05-28T05:54:26Z",
#         "temperature": 11.733807,
#         "relativeHumidity": 89.41848
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42317,
#           46.93716
#         ]
#       },
#       "properties": {
#         "stationId": "2340CBFEFFE70FFE",
#         "name": "Eisenbahnquartier",
#         "dateObserved": "2024-05-28T05:54:17Z",
#         "temperature": 11.234455,
#         "relativeHumidity": 94.44251
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43094,
#           46.94195
#         ]
#       },
#       "properties": {
#         "stationId": "4540CBFEFFE70FFE",
#         "name": "P\u00e4rkli bei Eigerplatz",
#         "dateObserved": "2024-05-28T05:54:12Z",
#         "temperature": 11.602961,
#         "relativeHumidity": 90.57435
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42805,
#           46.93514
#         ]
#       },
#       "properties": {
#         "stationId": "F4C450FEFF6E959E",
#         "name": "Steinh\u00f6lzliwald",
#         "dateObserved": "2024-05-28T05:54:11Z",
#         "temperature": 10.259785,
#         "relativeHumidity": 99.523766
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42252,
#           46.95291
#         ]
#       },
#       "properties": {
#         "stationId": "1740CBFEFFE70FFE",
#         "name": "VonRoll",
#         "dateObserved": "2024-05-28T05:54:06Z",
#         "temperature": 11.263828,
#         "relativeHumidity": 95.27032
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48201,
#           46.96241
#         ]
#       },
#       "properties": {
#         "stationId": "6B0551FEFF6E959E",
#         "name": "Ostermundigen Milchstrasse",
#         "dateObserved": "2024-05-28T05:54:01Z",
#         "temperature": 11.626993,
#         "relativeHumidity": 92.476006
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42771,
#           46.92253
#         ]
#       },
#       "properties": {
#         "stationId": "7ED650FEFF6E959E",
#         "name": "K\u00f6niz Blinzernplateau Strom-/Telefonmast",
#         "dateObserved": "2024-05-28T05:54:00Z",
#         "temperature": 10.927367,
#         "relativeHumidity": 88.569695
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45586,
#           46.94701
#         ]
#       },
#       "properties": {
#         "stationId": "1F40CBFEFFE70FFE",
#         "name": "Matte M\u00fchleplatz",
#         "dateObserved": "2024-05-28T05:53:57Z",
#         "temperature": 11.626993,
#         "relativeHumidity": 93.75777
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46146,
#           46.96017
#         ]
#       },
#       "properties": {
#         "stationId": "D43FCBFEFFE70FFE",
#         "name": "Tellstrasse",
#         "dateObserved": "2024-05-28T05:53:54Z",
#         "temperature": 11.570916,
#         "relativeHumidity": 91.08743
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49879,
#           46.95566
#         ]
#       },
#       "properties": {
#         "stationId": "D40451FEFF6E959E",
#         "name": "Ostermundigen Ahornstrasse 16",
#         "dateObserved": "2024-05-28T05:53:47Z",
#         "temperature": 10.935378,
#         "relativeHumidity": 95.859695
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.30584,
#           47.073505
#         ]
#       },
#       "properties": {
#         "stationId": "59E350FEFF6E959E",
#         "name": "Marktplatz Lyss",
#         "dateObserved": "2024-05-28T05:53:42Z",
#         "temperature": 12.0969715,
#         "relativeHumidity": 85.31571
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.299204,
#           47.071545
#         ]
#       },
#       "properties": {
#         "stationId": "7DE350FEFF6E959E",
#         "name": "Spielplatz Stiglimatt",
#         "dateObserved": "2024-05-28T05:53:28Z",
#         "temperature": 12.428092,
#         "relativeHumidity": 78.92409
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.51184,
#           46.89942
#         ]
#       },
#       "properties": {
#         "stationId": "4840CBFEFFE70FFE",
#         "name": "Umland Belp",
#         "dateObserved": "2024-05-28T05:53:26Z",
#         "temperature": 11.538873,
#         "relativeHumidity": 95.087204
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.386227,
#           46.928032
#         ]
#       },
#       "properties": {
#         "stationId": "10D850FEFF6E959E",
#         "name": "Niederwangen Papillon Laterne/Bush\u00e4uschen",
#         "dateObserved": "2024-05-28T05:53:19Z",
#         "temperature": 11.618982,
#         "relativeHumidity": 86.87976
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44009,
#           46.96286
#         ]
#       },
#       "properties": {
#         "stationId": "450551FEFF6E959E",
#         "name": "Viererfeld 3 (Strasse S\u00fcd)",
#         "dateObserved": "2024-05-28T05:53:17Z",
#         "temperature": 10.916686,
#         "relativeHumidity": 97.95781
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45045,
#           46.95597
#         ]
#       },
#       "properties": {
#         "stationId": "350551FEFF6E959E",
#         "name": "Optingenstrasse",
#         "dateObserved": "2024-05-28T05:53:10Z",
#         "temperature": 11.293202,
#         "relativeHumidity": 93.050125
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45192,
#           46.96173
#         ]
#       },
#       "properties": {
#         "stationId": "0240CBFEFFE70FFE",
#         "name": "Breitenrain, Waffenweg",
#         "dateObserved": "2024-05-28T05:53:05Z",
#         "temperature": 11.400015,
#         "relativeHumidity": 91.78363
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "230551FEFF6E959E",
#         "name": "Gurten Kulm 2",
#         "dateObserved": "2024-05-28T05:52:53Z",
#         "temperature": 11.653696,
#         "relativeHumidity": 91.28008
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.489671,
#           46.971962
#         ]
#       },
#       "properties": {
#         "stationId": "E2E250FEFF6E959E",
#         "name": "Ittigen Worblentalstrasse",
#         "dateObserved": "2024-05-28T05:52:52Z",
#         "temperature": 11.715114,
#         "relativeHumidity": 86.93889
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.456929,
#           46.99266
#         ]
#       },
#       "properties": {
#         "stationId": "5FE350FEFF6E959E",
#         "name": "Zollikofen Zentrum Laterne",
#         "dateObserved": "2024-05-28T05:52:52Z",
#         "temperature": 12.593652,
#         "relativeHumidity": 83.793625
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.477217,
#           46.974644
#         ]
#       },
#       "properties": {
#         "stationId": "95D650FEFF6E959E",
#         "name": "Ittigen Papierm\u00fchle Kreisel",
#         "dateObserved": "2024-05-28T05:52:50Z",
#         "temperature": 14.139772,
#         "relativeHumidity": 76.20035
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44353,
#           46.94692
#         ]
#       },
#       "properties": {
#         "stationId": "0140CBFEFFE70FFE",
#         "name": "Bundesplatz",
#         "dateObserved": "2024-05-28T05:52:47Z",
#         "temperature": 11.9100485,
#         "relativeHumidity": 88.827194
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48114,
#           46.95563
#         ]
#       },
#       "properties": {
#         "stationId": "D60451FEFF6E959E",
#         "name": "Ostermundigen B\u00e4reTower",
#         "dateObserved": "2024-05-28T05:52:45Z",
#         "temperature": 11.845961,
#         "relativeHumidity": 90.53239
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.484087,
#           46.947945
#         ]
#       },
#       "properties": {
#         "stationId": "1A40CBFEFFE70FFE",
#         "name": "Ostermundigen Tiefenm\u00f6sli",
#         "dateObserved": "2024-05-28T05:52:42Z",
#         "temperature": 11.274509,
#         "relativeHumidity": 96.899216
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50045,
#           46.93537
#         ]
#       },
#       "properties": {
#         "stationId": "FBDD50FEFF6E959E",
#         "name": "G\u00fcmligen (Worbstrasse) Laterne",
#         "dateObserved": "2024-05-28T05:52:33Z",
#         "temperature": 11.242466,
#         "relativeHumidity": 85.6762
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.310936,
#           47.075108
#         ]
#       },
#       "properties": {
#         "stationId": "3DD650FEFF6E959E",
#         "name": "Heilbachweg | Oberfeldweg",
#         "dateObserved": "2024-05-28T05:52:33Z",
#         "temperature": 12.454795,
#         "relativeHumidity": 81.254906
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48222,
#           46.95867
#         ]
#       },
#       "properties": {
#         "stationId": "460551FEFF6E959E",
#         "name": "Ostermundigen Poststrasse 2",
#         "dateObserved": "2024-05-28T05:52:31Z",
#         "temperature": 11.068894,
#         "relativeHumidity": 94.34333
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47992,
#           46.93919
#         ]
#       },
#       "properties": {
#         "stationId": "320551FEFF6E959E",
#         "name": "Murifeld",
#         "dateObserved": "2024-05-28T05:52:27Z",
#         "temperature": 11.234455,
#         "relativeHumidity": 94.93843
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47186,
#           46.95339
#         ]
#       },
#       "properties": {
#         "stationId": "060551FEFF6E959E",
#         "name": "Schosshaldenfriedhof 2",
#         "dateObserved": "2024-05-28T05:52:25Z",
#         "temperature": 11.490807,
#         "relativeHumidity": 89.05417
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37708,
#           46.94787
#         ]
#       },
#       "properties": {
#         "stationId": "0840CBFEFFE70FFE",
#         "name": "Ansermetplatz",
#         "dateObserved": "2024-05-28T05:52:23Z",
#         "temperature": 12.035554,
#         "relativeHumidity": 91.53185
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.480363,
#           46.957783
#         ]
#       },
#       "properties": {
#         "stationId": "0B0551FEFF6E959E",
#         "name": "Ostermundigen Schermenweg",
#         "dateObserved": "2024-05-28T05:52:15Z",
#         "temperature": 11.255817,
#         "relativeHumidity": 94.26513
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45656,
#           46.93798
#         ]
#       },
#       "properties": {
#         "stationId": "D03FCBFEFFE70FFE",
#         "name": "D\u00e4hlh\u00f6lzliwald",
#         "dateObserved": "2024-05-28T05:52:05Z",
#         "temperature": 10.636301,
#         "relativeHumidity": 102.091095
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48719,
#           46.95309
#         ]
#       },
#       "properties": {
#         "stationId": "1D40CBFEFFE70FFE",
#         "name": "Ostermundigen L\u00f6tschenstrasse 13",
#         "dateObserved": "2024-05-28T05:51:56Z",
#         "temperature": 11.157016,
#         "relativeHumidity": 95.487755
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46442,
#           46.94469
#         ]
#       },
#       "properties": {
#         "stationId": "090551FEFF6E959E",
#         "name": "Egelsee",
#         "dateObserved": "2024-05-28T05:51:55Z",
#         "temperature": 11.498817,
#         "relativeHumidity": 93.34196
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.490017,
#           46.980637
#         ]
#       },
#       "properties": {
#         "stationId": "C0C450FEFF6E959E",
#         "name": "Ittigen Gantrischweg 1 Laterne",
#         "dateObserved": "2024-05-28T05:51:53Z",
#         "temperature": 10.988785,
#         "relativeHumidity": 86.44488
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45351,
#           46.9481
#         ]
#       },
#       "properties": {
#         "stationId": "E4C450FEFF6E959E",
#         "name": "Gerechtigkeitsgasse",
#         "dateObserved": "2024-05-28T05:51:52Z",
#         "temperature": 12.33196,
#         "relativeHumidity": 87.457695
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40633,
#           46.94333
#         ]
#       },
#       "properties": {
#         "stationId": "2F40CBFEFFE70FFE",
#         "name": "Europaplatz 2",
#         "dateObserved": "2024-05-28T05:51:49Z",
#         "temperature": 11.827268,
#         "relativeHumidity": 89.24681
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.481124,
#           46.926167
#         ]
#       },
#       "properties": {
#         "stationId": "61E350FEFF6E959E",
#         "name": "Muri Bl\u00fcmlisalpstrasse",
#         "dateObserved": "2024-05-28T05:51:49Z",
#         "temperature": 11.274509,
#         "relativeHumidity": 87.65415
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45824,
#           46.94059
#         ]
#       },
#       "properties": {
#         "stationId": "0A40CBFEFFE70FFE",
#         "name": "Thunplatz",
#         "dateObserved": "2024-05-28T05:51:41Z",
#         "temperature": 11.458762,
#         "relativeHumidity": 94.4921
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.319325,
#           47.098705
#         ]
#       },
#       "properties": {
#         "stationId": "A4E250FEFF6E959E",
#         "name": "Bahnhofplatz Busswil",
#         "dateObserved": "2024-05-28T05:51:39Z",
#         "temperature": 12.655069,
#         "relativeHumidity": 75.52705
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.471829,
#           46.94506
#         ]
#       },
#       "properties": {
#         "stationId": "B9C450FEFF6E959E",
#         "name": "Bern-Ostring Freudenbergplatz Laterne",
#         "dateObserved": "2024-05-28T05:51:29Z",
#         "temperature": 11.432059,
#         "relativeHumidity": 87.10864
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.498633,
#           46.892506
#         ]
#       },
#       "properties": {
#         "stationId": "30E450FEFF6E959E",
#         "name": "Belp Zentrum Laterne",
#         "dateObserved": "2024-05-28T05:51:26Z",
#         "temperature": 12.062257,
#         "relativeHumidity": 82.20668
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44248,
#           46.90961
#         ]
#       },
#       "properties": {
#         "stationId": "4B40CBFEFFE70FFE",
#         "name": "K\u00f6niztal",
#         "dateObserved": "2024-05-28T05:51:20Z",
#         "temperature": 10.409324,
#         "relativeHumidity": 100.03685
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43541,
#           46.95789
#         ]
#       },
#       "properties": {
#         "stationId": "CD3FCBFEFFE70FFE",
#         "name": "Hintere L\u00e4nggasse",
#         "dateObserved": "2024-05-28T05:51:18Z",
#         "temperature": 11.418708,
#         "relativeHumidity": 90.05173
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46747,
#           46.9645
#         ]
#       },
#       "properties": {
#         "stationId": "E4EA50FEFF6E959E",
#         "name": "Bern Wankdorfplatz Laterne",
#         "dateObserved": "2024-05-28T05:51:15Z",
#         "temperature": 11.7978945,
#         "relativeHumidity": 84.316246
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4133654,
#           46.938255
#         ]
#       },
#       "properties": {
#         "stationId": "D7DD50FEFF6E959E",
#         "name": "Liebefeld Turnierstrasse Laterne",
#         "dateObserved": "2024-05-28T05:51:13Z",
#         "temperature": 10.390631,
#         "relativeHumidity": 92.325325
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45326,
#           46.93122
#         ]
#       },
#       "properties": {
#         "stationId": "3740CBFEFFE70FFE",
#         "name": "Wabern Viktoriastrasse",
#         "dateObserved": "2024-05-28T05:51:07Z",
#         "temperature": 11.488136,
#         "relativeHumidity": 94.27276
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41688,
#           46.94211
#         ]
#       },
#       "properties": {
#         "stationId": "1140CBFEFFE70FFE",
#         "name": "Schlossmatte Familieng\u00e4rten",
#         "dateObserved": "2024-05-28T05:51:04Z",
#         "temperature": 11.939422,
#         "relativeHumidity": 94.783936
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42946,
#           46.94672
#         ]
#       },
#       "properties": {
#         "stationId": "9FD350FEFF6E959E",
#         "name": "Emch+Berger (Schl\u00f6sslistrasse) Pfosten Eingang",
#         "dateObserved": "2024-05-28T05:51:03Z",
#         "temperature": 11.813916,
#         "relativeHumidity": 80.29168
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48807,
#           46.95813
#         ]
#       },
#       "properties": {
#         "stationId": "0F40CBFEFFE70FFE",
#         "name": "Ostermuniugen Moosweg",
#         "dateObserved": "2024-05-28T05:51:01Z",
#         "temperature": 11.501488,
#         "relativeHumidity": 94.32998
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4285746,
#           46.95617
#         ]
#       },
#       "properties": {
#         "stationId": "593FCBFEFFE70FFE",
#         "name": "Bern Hintere L\u00e4nggasse",
#         "dateObserved": "2024-05-28T05:50:58Z",
#         "temperature": 11.560235,
#         "relativeHumidity": 83.11841
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48214,
#           46.95869
#         ]
#       },
#       "properties": {
#         "stationId": "2840CBFEFFE70FFE",
#         "name": "Ostermundigen Poststrasse",
#         "dateObserved": "2024-05-28T05:50:47Z",
#         "temperature": 11.076905,
#         "relativeHumidity": 93.21034
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.712437,
#           46.713448
#         ]
#       },
#       "properties": {
#         "stationId": "4640CBFEFFE70FFE",
#         "name": "Sigriswil",
#         "dateObserved": "2024-05-28T05:50:39Z",
#         "temperature": 9.966048,
#         "relativeHumidity": 90.80705
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45802,
#           46.95696
#         ]
#       },
#       "properties": {
#         "stationId": "4940CBFEFFE70FFE",
#         "name": "Kasernenareal",
#         "dateObserved": "2024-05-28T05:50:32Z",
#         "temperature": 11.359961,
#         "relativeHumidity": 93.39918
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4695,
#           46.93558
#         ]
#       },
#       "properties": {
#         "stationId": "1E40CBFEFFE70FFE",
#         "name": "Elfenau",
#         "dateObserved": "2024-05-28T05:50:27Z",
#         "temperature": 11.258488,
#         "relativeHumidity": 96.735176
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43462,
#           46.94187
#         ]
#       },
#       "properties": {
#         "stationId": "0640CBFEFFE70FFE",
#         "name": "Monbijou-Park",
#         "dateObserved": "2024-05-28T05:50:27Z",
#         "temperature": 11.498817,
#         "relativeHumidity": 93.44305
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45935,
#           46.92921
#         ]
#       },
#       "properties": {
#         "stationId": "17D950FEFF6E959E",
#         "name": "Wabern Weyergut",
#         "dateObserved": "2024-05-28T05:50:21Z",
#         "temperature": 11.162356,
#         "relativeHumidity": 88.76044
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45978,
#           46.97857
#         ]
#       },
#       "properties": {
#         "stationId": "1EDE50FEFF6E959E",
#         "name": "Ittigen Worblaufenstrasse  Laterne",
#         "dateObserved": "2024-05-28T05:50:15Z",
#         "temperature": 12.000839,
#         "relativeHumidity": 85.485466
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4540253,
#           46.958252
#         ]
#       },
#       "properties": {
#         "stationId": "1540CBFEFFE70FFE",
#         "name": "Breitenrainplatz 127",
#         "dateObserved": "2024-05-28T05:50:12Z",
#         "temperature": 11.651026,
#         "relativeHumidity": 90.7441
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43688,
#           46.96271
#         ]
#       },
#       "properties": {
#         "stationId": "1240CBFEFFE70FFE",
#         "name": "Viererfeld 2 (Schacht)",
#         "dateObserved": "2024-05-28T05:50:10Z",
#         "temperature": 11.616312,
#         "relativeHumidity": 91.13893
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.525039,
#           46.9585
#         ]
#       },
#       "properties": {
#         "stationId": "2BD650FEFF6E959E",
#         "name": "Stettlen Bernstrasse Laterne",
#         "dateObserved": "2024-05-28T05:50:04Z",
#         "temperature": 11.60029,
#         "relativeHumidity": 84.983826
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46407,
#           46.99079
#         ]
#       },
#       "properties": {
#         "stationId": "3B40CBFEFFE70FFE",
#         "name": "Zollikofen 3m",
#         "dateObserved": "2024-05-28T05:50:01Z",
#         "temperature": 12.24918,
#         "relativeHumidity": 94.98802
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44007,
#           46.93354
#         ]
#       },
#       "properties": {
#         "stationId": "11D450FEFF6E959E",
#         "name": "Morillongut (Sch\u00f6negg) Mast",
#         "dateObserved": "2024-05-28T05:49:32Z",
#         "temperature": 12.00885,
#         "relativeHumidity": 86.31518
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.448146,
#           46.93012
#         ]
#       },
#       "properties": {
#         "stationId": "B8D350FEFF6E959E",
#         "name": "Wabern Zentrum Laterne",
#         "dateObserved": "2024-05-28T05:49:23Z",
#         "temperature": 11.456092,
#         "relativeHumidity": 85.464485
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40995,
#           46.92041
#         ]
#       },
#       "properties": {
#         "stationId": "0A0551FEFF6E959E",
#         "name": "K\u00f6niz Aussenquartier",
#         "dateObserved": "2024-05-28T05:49:23Z",
#         "temperature": 11.071565,
#         "relativeHumidity": 94.64469
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42571,
#           46.94719
#         ]
#       },
#       "properties": {
#         "stationId": "DA0451FEFF6E959E",
#         "name": "Inselspital",
#         "dateObserved": "2024-05-28T05:49:16Z",
#         "temperature": 12.620356,
#         "relativeHumidity": 84.51461
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44571,
#           46.94445
#         ]
#       },
#       "properties": {
#         "stationId": "E40451FEFF6E959E",
#         "name": "Dalmazibr\u00fccke",
#         "dateObserved": "2024-05-28T05:49:12Z",
#         "temperature": 11.418708,
#         "relativeHumidity": 91.423134
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "100551FEFF6E959E",
#         "name": "Gurten Kulm",
#         "dateObserved": "2024-05-28T05:49:10Z",
#         "temperature": 9.469368,
#         "relativeHumidity": 89.99832
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37676,
#           46.96736
#         ]
#       },
#       "properties": {
#         "stationId": "7FEA50FEFF6E959E",
#         "name": "Wohlen Hinterkappelenring Laterne",
#         "dateObserved": "2024-05-28T05:49:06Z",
#         "temperature": 11.573586,
#         "relativeHumidity": 92.16319
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41453,
#           46.92282
#         ]
#       },
#       "properties": {
#         "stationId": "FED550FEFF6E959E",
#         "name": "K\u00f6niz Bl\u00e4uacker Park Aldi/Swisscom",
#         "dateObserved": "2024-05-28T05:49:05Z",
#         "temperature": 11.0421915,
#         "relativeHumidity": 87.200195
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.377091,
#           46.92567
#         ]
#       },
#       "properties": {
#         "stationId": "76DA50FEFF6E959E",
#         "name": "Niederwangen Zentrum Laterne",
#         "dateObserved": "2024-05-28T05:49:04Z",
#         "temperature": 10.95674,
#         "relativeHumidity": 88.691765
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.305877,
#           47.07661
#         ]
#       },
#       "properties": {
#         "stationId": "64E350FEFF6E959E",
#         "name": "Monopoliplatz Lyss",
#         "dateObserved": "2024-05-28T05:49:03Z",
#         "temperature": 12.558938,
#         "relativeHumidity": 76.3148
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44773,
#           46.95518
#         ]
#       },
#       "properties": {
#         "stationId": "130551FEFF6E959E",
#         "name": "Viktoriarain",
#         "dateObserved": "2024-05-28T05:48:58Z",
#         "temperature": 11.389334,
#         "relativeHumidity": 91.40215
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49371,
#           46.95806
#         ]
#       },
#       "properties": {
#         "stationId": "280551FEFF6E959E",
#         "name": "Ostermundigen Wegm\u00fchleng\u00e4ssli",
#         "dateObserved": "2024-05-28T05:48:46Z",
#         "temperature": 11.143663,
#         "relativeHumidity": 96.08476
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37478,
#           46.94555
#         ]
#       },
#       "properties": {
#         "stationId": "E00451FEFF6E959E",
#         "name": "Westside Center",
#         "dateObserved": "2024-05-28T05:48:44Z",
#         "temperature": 10.9113455,
#         "relativeHumidity": 96.28504
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46257,
#           46.96311
#         ]
#       },
#       "properties": {
#         "stationId": "3340CBFEFFE70FFE",
#         "name": "Stadtlabor",
#         "dateObserved": "2024-05-28T05:48:38Z",
#         "temperature": 11.512169,
#         "relativeHumidity": 91.66346
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43786,
#           46.94658
#         ]
#       },
#       "properties": {
#         "stationId": "ED3FCBFEFFE70FFE",
#         "name": "Hirschengraben",
#         "dateObserved": "2024-05-28T05:48:33Z",
#         "temperature": 11.546884,
#         "relativeHumidity": 87.95361
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.308954,
#           47.0709
#         ]
#       },
#       "properties": {
#         "stationId": "24E350FEFF6E959E",
#         "name": "M\u00fchleplatz Lyss",
#         "dateObserved": "2024-05-28T05:48:33Z",
#         "temperature": 12.110323,
#         "relativeHumidity": 82.855194
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40134,
#           46.949
#         ]
#       },
#       "properties": {
#         "stationId": "C33FCBFEFFE70FFE",
#         "name": "Weyermannshaus Industrie 2",
#         "dateObserved": "2024-05-28T05:48:30Z",
#         "temperature": 12.227818,
#         "relativeHumidity": 87.40238
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44082,
#           46.95151
#         ]
#       },
#       "properties": {
#         "stationId": "0F0551FEFF6E959E",
#         "name": "Bollwerk Strasseninsel",
#         "dateObserved": "2024-05-28T05:48:30Z",
#         "temperature": 12.225147,
#         "relativeHumidity": 87.837265
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.481412,
#           46.94348
#         ]
#       },
#       "properties": {
#         "stationId": "5AE350FEFF6E959E",
#         "name": "Bern Merzenacker",
#         "dateObserved": "2024-05-28T05:48:22Z",
#         "temperature": 11.052873,
#         "relativeHumidity": 85.85359
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49792,
#           46.9581
#         ]
#       },
#       "properties": {
#         "stationId": "020551FEFF6E959E",
#         "name": "Ostermundigen Oberfeld",
#         "dateObserved": "2024-05-28T05:48:16Z",
#         "temperature": 10.9300375,
#         "relativeHumidity": 94.00763
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43739,
#           46.92607
#         ]
#       },
#       "properties": {
#         "stationId": "200551FEFF6E959E",
#         "name": "Spiegel",
#         "dateObserved": "2024-05-28T05:48:15Z",
#         "temperature": 11.290532,
#         "relativeHumidity": 92.813614
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.301668,
#           47.077145
#         ]
#       },
#       "properties": {
#         "stationId": "E3E250FEFF6E959E",
#         "name": "Reitplatz Gr\u00fcnau",
#         "dateObserved": "2024-05-28T05:48:14Z",
#         "temperature": 11.92073,
#         "relativeHumidity": 83.31487
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44894,
#           46.94391
#         ]
#       },
#       "properties": {
#         "stationId": "EB3FCBFEFFE70FFE",
#         "name": "Helvetiaplatz neu",
#         "dateObserved": "2024-05-28T05:48:08Z",
#         "temperature": 11.699092,
#         "relativeHumidity": 89.67788
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46987,
#           46.95063
#         ]
#       },
#       "properties": {
#         "stationId": "410551FEFF6E959E",
#         "name": "Galgenfeld Neubausiedlung",
#         "dateObserved": "2024-05-28T05:47:59Z",
#         "temperature": 11.295873,
#         "relativeHumidity": 95.81964
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42015,
#           46.9503
#         ]
#       },
#       "properties": {
#         "stationId": "1440CBFEFFE70FFE",
#         "name": "Bremgartenfriedhof",
#         "dateObserved": "2024-05-28T05:47:54Z",
#         "temperature": 11.245136,
#         "relativeHumidity": 95.48203
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40896,
#           46.92981
#         ]
#       },
#       "properties": {
#         "stationId": "62E350FEFF6E959E",
#         "name": "K\u00f6niz Gartenstadt Laterne",
#         "dateObserved": "2024-05-28T05:47:46Z",
#         "temperature": 11.082246,
#         "relativeHumidity": 89.43374
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50944,
#           46.9377
#         ]
#       },
#       "properties": {
#         "stationId": "B3C450FEFF6E959E",
#         "name": "G\u00fcmligen Dentenberg Laterne",
#         "dateObserved": "2024-05-28T05:47:44Z",
#         "temperature": 10.46807,
#         "relativeHumidity": 90.01358
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.445022,
#           46.95565
#         ]
#       },
#       "properties": {
#         "stationId": "A9E450FEFF6E959E",
#         "name": "Bern Lorrainepark",
#         "dateObserved": "2024-05-28T05:47:43Z",
#         "temperature": 11.341268,
#         "relativeHumidity": 82.43748
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4986053,
#           46.92633
#         ]
#       },
#       "properties": {
#         "stationId": "B7D350FEFF6E959E",
#         "name": "Muri Steinh\u00fcbeliweg",
#         "dateObserved": "2024-05-28T05:47:40Z",
#         "temperature": 11.002136,
#         "relativeHumidity": 85.87839
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42031,
#           46.92781
#         ]
#       },
#       "properties": {
#         "stationId": "2C40CBFEFFE70FFE",
#         "name": "K\u00f6niz Neubausiedlung",
#         "dateObserved": "2024-05-28T05:47:27Z",
#         "temperature": 11.063554,
#         "relativeHumidity": 94.03433
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48628,
#           46.93048
#         ]
#       },
#       "properties": {
#         "stationId": "693FCBFEFFE70FFE",
#         "name": "Muri Zentrum (Tavelweg) Laterne",
#         "dateObserved": "2024-05-28T05:47:18Z",
#         "temperature": 11.392004,
#         "relativeHumidity": 87.730446
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4377694,
#           46.938946
#         ]
#       },
#       "properties": {
#         "stationId": "D4C050FEFF6E959E",
#         "name": "Bern Sulgenau",
#         "dateObserved": "2024-05-28T05:47:01Z",
#         "temperature": 11.808576,
#         "relativeHumidity": 85.73533
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.464513,
#           46.90957
#         ]
#       },
#       "properties": {
#         "stationId": "E8E450FEFF6E959E",
#         "name": "Kehrsatz Breit\u00e4gertenstrasse Laterne",
#         "dateObserved": "2024-05-28T05:46:58Z",
#         "temperature": 10.9861145,
#         "relativeHumidity": 87.55306
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40642,
#           46.94542
#         ]
#       },
#       "properties": {
#         "stationId": "010551FEFF6E959E",
#         "name": "Ausserholligen 2, ewb",
#         "dateObserved": "2024-05-28T05:46:57Z",
#         "temperature": 11.755169,
#         "relativeHumidity": 90.47707
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.455911,
#           46.92579
#         ]
#       },
#       "properties": {
#         "stationId": "E7E450FEFF6E959E",
#         "name": "Wabern Gartentower Laterne",
#         "dateObserved": "2024-05-28T05:46:45Z",
#         "temperature": 11.541543,
#         "relativeHumidity": 85.638054
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.5102544,
#           47.01997
#         ]
#       },
#       "properties": {
#         "stationId": "2940CBFEFFE70FFE",
#         "name": "Urtenen-Sch\u00f6nb\u00fchl (3322)",
#         "dateObserved": "2024-05-28T05:46:26Z",
#         "temperature": 10.767147,
#         "relativeHumidity": 93.3534
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41466,
#           46.92327
#         ]
#       },
#       "properties": {
#         "stationId": "FCE350FEFF6E959E",
#         "name": "K\u00f6niz Bl\u00e4uacker Kandelaber auf Platz  ",
#         "dateObserved": "2024-05-28T05:46:16Z",
#         "temperature": 11.039521,
#         "relativeHumidity": 85.72007
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.311275,
#           47.078552
#         ]
#       },
#       "properties": {
#         "stationId": "2FE450FEFF6E959E",
#         "name": "Schulhaus Grentschel",
#         "dateObserved": "2024-05-28T05:45:56Z",
#         "temperature": 12.032884,
#         "relativeHumidity": 81.63256
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43714,
#           46.9517
#         ]
#       },
#       "properties": {
#         "stationId": "D53FCBFEFFE70FFE",
#         "name": "L\u00e4nggasse Falkenweg",
#         "dateObserved": "2024-05-28T05:44:28Z",
#         "temperature": 11.034181,
#         "relativeHumidity": 95.56977
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.451387,
#           46.99095
#         ]
#       },
#       "properties": {
#         "stationId": "40DE50FEFF6E959E",
#         "name": "Zollikofen Reichenbach Laterne",
#         "dateObserved": "2024-05-28T05:29:36Z",
#         "temperature": 10.940719,
#         "relativeHumidity": 89.981155
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44122,
#           46.97417
#         ]
#       },
#       "properties": {
#         "stationId": "D83FCBFEFFE70FFE",
#         "name": "Felsenhaldeweg",
#         "dateObserved": "2024-05-28T05:29:27Z",
#         "temperature": 10.815213,
#         "relativeHumidity": 97.423744
#       }
#     }
#   ]
# }

# %% [markdown]
# Loading the data as GeoPandas dataframe improves the readability of the data in a single step:

# %%
stations = gpd.read_file(response.text)

# Display stations DataFrame
stations
# Out:
#             stationId                                               name  \
# 0    1040CBFEFFE70FFE                        Viererfeld 4 (Strasse Nord)
# 1    4DE350FEFF6E959E                                 Industriering Nord
# 2    3940CBFEFFE70FFE                                      Laupenstrasse
# 3    57D550FEFF6E959E  Bremgarten Ecke Lindenstrasse / Ritterstrasse ...
# 4    FE3FCBFEFFE70FFE                                     Bubenbergplatz
# ..                ...                                                ...
# 118  FCE350FEFF6E959E             Köniz Bläuacker Kandelaber auf Platz
# 119  2FE450FEFF6E959E                               Schulhaus Grentschel
# 120  D53FCBFEFFE70FFE                                Länggasse Falkenweg
# 121  40DE50FEFF6E959E                     Zollikofen Reichenbach Laterne
# 122  D83FCBFEFFE70FFE                                     Felsenhaldeweg
#
#                  dateObserved  temperature  relativeHumidity  \
# 0   2024-05-28 05:56:37+00:00    11.165027         96.407110
# 1   2024-05-28 05:56:13+00:00    12.556268         75.738760
# 2   2024-05-28 05:56:12+00:00    11.872663         89.048450
# 3   2024-05-28 05:56:12+00:00    11.429389         90.849014
# 4   2024-05-28 05:56:12+00:00    12.155718         86.498280
# ..                        ...          ...               ...
# 118 2024-05-28 05:46:16+00:00    11.039521         85.720070
# 119 2024-05-28 05:45:56+00:00    12.032884         81.632560
# 120 2024-05-28 05:44:28+00:00    11.034181         95.569770
# 121 2024-05-28 05:29:36+00:00    10.940719         89.981155
# 122 2024-05-28 05:29:27+00:00    10.815213         97.423744
#
#                      geometry
# 0    POINT (7.44165 46.96523)
# 1    POINT (7.30673 47.08913)
# 2    POINT (7.43639 46.94734)
# 3    POINT (7.43882 46.97791)
# 4    POINT (7.43843 46.94728)
# ..                        ...
# 118  POINT (7.41466 46.92327)
# 119  POINT (7.31128 47.07855)
# 120  POINT (7.43714 46.95170)
# 121  POINT (7.45139 46.99095)
# 122  POINT (7.44122 46.97417)
#
# [123 rows x 6 columns]

# %% [markdown]
# ### Step 3: Visualisation on a map
#
# To start with, here is the code to display a map. It is automatically centered according to the average longitude and latitude of the weather stations.

# %%
# Create a base map
map1 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=10)

# Display map
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2de492e0b038817f0b2bc19f2edaa9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2de492e0b038817f0b2bc19f2edaa9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2de492e0b038817f0b2bc19f2edaa9b = L.map(
#                 &quot;map_d2de492e0b038817f0b2bc19f2edaa9b&quot;,
#                 {
#                     center: [46.95548891869918, 7.442509011382114],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a358bd6ca2ced56720c34e6dafd1a3c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d2de492e0b038817f0b2bc19f2edaa9b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Second, we display the location of the weather stations, but without weather data measurements:

# %%
# Create a base map
map2 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=10)

# Iterate through each station in the GeoPandas DataFrame
for idx, station in stations.iterrows():
    # Create a circle marker for each station and add it to the map
    folium.CircleMarker(
        # Location of the marker in lat and lon
        location=(station.geometry.y, station.geometry.x),
        # Styling the marker
        radius=5,
        color="black",  # Border color
        weight=0.5,  # Border width
        fill=True,
        fill_color="black",
        fill_opacity=1, # 1 means 100% opaque
        # Add a tooltip with station name
        tooltip=f"{station['name']}",
    # Add the marker to the map
    ).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1410a4e999f20234f5e825de9e06ebfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1410a4e999f20234f5e825de9e06ebfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1410a4e999f20234f5e825de9e06ebfc = L.map(
#                 &quot;map_1410a4e999f20234f5e825de9e06ebfc&quot;,
#                 {
#                     center: [46.95548891869918, 7.442509011382114],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c333ee672c558402d666bae4bdf6943a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1410a4e999f20234f5e825de9e06ebfc);
#
#
#             var circle_marker_bcf28a61cda9aeab7ba0f507bb3b7ce6 = L.circleMarker(
#                 [46.96523, 7.44165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_1410a4e999f20234f5e825de9e06ebfc);
#
#
#             circle_marker_bcf28a61cda9aeab7ba0f507bb3b7ce6.bindTooltip(
#                 `&lt;div&gt;
#                      Viererfeld 4 (Strasse Nord)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b222d4da7e7748462cc1cc9edf81cea6 = L.circleMarker(
#                 [47.089134, 7.30673],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_1410a4e999f20234f5e825de9e06ebfc);
#
#
#             circle_marker_b222d4da7e7748462cc1cc9edf81cea6.bindTooltip(
#                 `&lt;div&gt;
#                      Industriering Nord
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_0c6d393633a19c2390d0f15458ccea6a = L.circleMarker(
#                 [46.94734, 7.43639],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_1410a4e999f20234f5e825de9e06ebfc);
#
#
#             circle_marker_0c6d393633a19c2390d0f15458ccea6a.bindTooltip(
#                 `&lt;div&gt;
#                      Laupenstrasse
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_3c683299656b2a41f944904dd03656b9 = L.circleMarker(
#                 [46.977913, 7.438822],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_1410a4e999f20234f5e825de9e06ebfc);
#
#
#             circle_marker_3c683299656b2a41f944904dd03656b9.bindTooltip(
#                 `&lt;div&gt;
#                      Bremgarten Ecke Lindenstrasse / Ritterstrasse Laterne
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_eec002ff561f0d638547e09375f7d7db = L.circleMarker(
#                 [46.94728, 7.43843],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;eveno

# %% [markdown]
# And finally, we can give the weather stations a colour depending on the current temperature and also add tooltips:

# %%
# Create a base map
map3 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=13)#, tiles="CartoDB positron")

# Most popular colormaps are sequential, meaning that they have a start and end color
# Define a function to reverse a colormap
def reversed_colormap(existing):
    return branca.colormap.LinearColormap(
        colors=list(reversed(existing.colors)),
        vmin=existing.vmin, vmax=existing.vmax
    )

def formatToolTip(stationName, temperature, humidity):
    return f"{stationName}: {temperature:.2f}°C, {humidity:.2f}%"

def formatToolTip2(stationName, temperature, humidity):
    return f"<h4>{stationName}</h4>Temperature: {temperature:.2f}°C<br/>Humidity: {humidity:.2f}%"


# Create a colormap for a temperature range of 10-37°C
# Choose an appropriate colormap (Spectral_11) and reverse it so that it goes from blue (cold) to red (hot)
colormap = reversed_colormap(branca.colormap.linear.Spectral_11)
# Scale the colormap to the temperature range and discretize it into 9 steps for better visibility
colormap = colormap.scale(0, 20).to_step(9)
# Add a caption to the colormap
colormap.caption = "Temperature (°C)"
# Add colormap to the map
colormap.add_to(map3)

# Iterate through each station in the GeoPandas DataFrame
for idx, station in stations.iterrows():
    # Create a circle marker for each station and add it to the map
    folium.CircleMarker(
        # Location of the marker in lon and lat
        location=(station.geometry.y, station.geometry.x),
        # Styling the marker
        radius=5,
        color="black",  # Border color
        weight=0.5,  # Border width
        fill=True,
        # Set the fill color to the colormap value corresponding to the station temperature
        fill_color=colormap(station['temperature']),
        fill_opacity=1, # 1 means 100% opaque
        # Add a tooltip with station name and temperature
        tooltip=formatToolTip2(station['name'], station['temperature'], station['relativeHumidity'])
    # Add the marker to the map
    ).add_to(map3)

# Display map
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df93f244cb0fcc6ea7731a05c7712971 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df93f244cb0fcc6ea7731a05c7712971&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df93f244cb0fcc6ea7731a05c7712971 = L.map(
#                 &quot;map_df93f244cb0fcc6ea7731a05c7712971&quot;,
#                 {
#                     center: [46.95548891869918, 7.442509011382114],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de924a025153f20dbe7fe0602a193b91 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df93f244cb0fcc6ea7731a05c7712971);
#
#
#     var color_map_31b7709ce704713abf6e9f499fb79b9e = {};
#
#
#     color_map_31b7709ce704713abf6e9f499fb79b9e.color = d3.scale.threshold()
#               .domain([0.0, 0.04008016032064128, 0.08016032064128256, 0.12024048096192384, 0.16032064128256512, 0.20040080160320642, 0.24048096192384769, 0.280561122244489, 0.32064128256513025, 0.36072144288577157, 0.40080160320641284, 0.4408817635270541, 0.48096192384769537, 0.5210420841683366, 0.561122244488978, 0.6012024048096193, 0.6412825651302605, 0.6813627254509018, 0.7214428857715431, 0.7615230460921844, 0.8016032064128257, 0.8416833667334669, 0.8817635270541082, 0.9218436873747495, 0.9619238476953907, 1.002004008016032, 1.0420841683366733, 1.0821643286573146, 1.122244488977956, 1.1623246492985972, 1.2024048096192386, 1.2424849699398797, 1.282565130260521, 1.3226452905811623, 1.3627254509018036, 1.402805611222445, 1.4428857715430863, 1.4829659318637274, 1.5230460921843687, 1.56312625250501, 1.6032064128256514, 1.6432865731462927, 1.6833667334669338, 1.723446893787575, 1.7635270541082164, 1.8036072144288577, 1.843687374749499, 1.8837675350701404, 1.9238476953907815, 1.9639278557114228, 2.004008016032064, 2.0440881763527052, 2.0841683366733466, 2.124248496993988, 2.164328657314629, 2.2044088176352705, 2.244488977955912, 2.284569138276553, 2.3246492985971945, 2.364729458917836, 2.404809619238477, 2.444889779559118, 2.4849699398797593, 2.5250501002004007, 2.565130260521042, 2.6052104208416833, 2.6452905811623246, 2.685370741482966, 2.7254509018036073, 2.7655310621242486, 2.80561122244489, 2.8456913827655312, 2.8857715430861726, 2.9258517034068134, 2.9659318637274548, 3.006012024048096, 3.0460921843687374, 3.0861723446893787, 3.12625250501002, 3.1663326653306614, 3.2064128256513027, 3.246492985971944, 3.2865731462925853, 3.3266533066132267, 3.3667334669338675, 3.406813627254509, 3.44689378757515, 3.4869739478957915, 3.527054108216433, 3.567134268537074, 3.6072144288577155, 3.647294589178357, 3.687374749498998, 3.7274549098196395, 3.7675350701402808, 3.8076152304609217, 3.847695390781563, 3.8877755511022043, 3.9278557114228456, 3.967935871743487, 4.008016032064128, 4.04809619238477, 4.0881763527054105, 4.128256513026052, 4.168336673346693, 4.208416833667335, 4.248496993987976, 4.2885771543086175, 4.328657314629258, 4.3687374749499, 4.408817635270541, 4.448897795591182, 4.488977955911824, 4.529058116232465, 4.569138276553106, 4.609218436873747, 4.649298597194389, 4.68937875751503, 4.729458917835672, 4.7695390781563125, 4.809619238476954, 4.849699398797595, 4.889779559118236, 4.929859719438878, 4.969939879759519, 5.01002004008016, 5.050100200400801, 5.090180360721443, 5.130260521042084, 5.170340681362726, 5.210420841683367, 5.250501002004008, 5.290581162324649, 5.330661322645291, 5.370741482965932, 5.410821643286573, 5.4509018036072145, 5.490981963927855, 5.531062124248497, 5.571142284569138, 5.61122244488978, 5.651302605210421, 5.6913827655310625, 5.731462925851703, 5.771543086172345, 5.811623246492986, 5.851703406813627, 5.891783567134269, 5.9318637274549095, 5.971943887775551, 6.012024048096192, 6.052104208416834, 6.092184368737475, 6.132264529058117, 6.1723446893787575, 6.212424849699399, 6.25250501002004, 6.292585170340681, 6.332665330661323, 6.372745490981964, 6.412825651302605, 6.452905811623246, 6.492985971943888, 6.533066132264529, 6.573146292585171, 6.613226452905812, 6.653306613226453, 6.693386773547094, 6.733466933867735, 6.773547094188377, 6.813627254509018, 6.8537074148296595, 6.8937875751503, 6.933867735470942, 6.973947895791583, 7.014028056112225, 7.054108216432866, 7.094188376753507, 7.134268537074148, 7.174348697394789, 7.214428857715431, 7.254509018036072, 7.294589178356714, 7.3346693386773545, 7.374749498997996, 7.414829659318637, 7.454909819639279, 7.49498997995992, 7.5350701402805615, 7.575150300601202, 7.615230460921843, 7.655310621242485, 7.695390781563126, 7.735470941883768, 7.775551102204409, 7.81563126252505, 7.8557114228456

# %% [markdown]
# ## Part 2 - Display Measurement Data over Time

# %% [markdown]
# ### Step 1: Query data for a specific weather station
#
# e.g., at the Government Plaza ("Bundesplatz" in German):

# %%
# Based on a station name, get the respective stationId from the DataFrame
stationId = stations[stations["name"] == "Bundesplatz"].stationId.values[0]
# Define the URL including the stationId argument
url = f"https://smart-urban-heat-map.ch/api/1.0/timeseries?stationId={stationId}"

# Define the headers to request CSV data as a python dictionary
headers = {
    "Accept": "text/csv"
}

# Make the GET request with the headers
response = requests.get(url, headers=headers)

# Get the timeseries into a data frame
timeseries = pd.read_csv(io.StringIO(response.text), delimiter=";")

timeseries
# Out:
#           dateObserved  temperature  relativeHumidity
# 0    2024-05-26T06:02Z    12.764553         75.887540
# 1    2024-05-26T06:12Z    13.047608         74.884260
# 2    2024-05-26T06:22Z    13.173114         74.298700
# 3    2024-05-26T06:32Z    13.490883         73.753190
# 4    2024-05-26T06:42Z    14.374762         71.746620
# ..                 ...          ...               ...
# 282  2024-05-28T05:12Z    11.258488         89.260170
# 283  2024-05-28T05:22Z    11.549554         88.621190
# 284  2024-05-28T05:32Z    11.771191         88.275960
# 285  2024-05-28T05:42Z    11.744488         88.848175
# 286  2024-05-28T05:52Z    11.910049         88.827194
#
# [287 rows x 3 columns]

# %% [markdown]
# ### Step 2: Show data in a graph
#
# By default, the data from the last 48 hours is returned.

# %%
# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
ax = timeseries.plot(x='dateObserved', y='temperature', figsize=(10,6), marker=None, linestyle='-')
# The ax object is a matplotlib axis object which we can use to further customize the plot

# Add a title
ax.set_title('Bundesplatz')

# Add labels for the x and y axes
ax.set_xlabel('Time')
ax.set_ylabel('Temperature (°C)')

# Shift every second x-label for better readability
for i, label in enumerate(ax.get_xticklabels()):
    if i % 2 == 0:  # Check if it's an odd tick
        label.set_y(-0.04)

# %% [markdown]
# ### Step 3: Display data from multiple stations in a specific time period
# First, we set the time period:

# %%
startTime = "2024-04-28T00:00:00Z" # 28.09.23 00:00 ; Z means UTC time
endTime = "2024-04-30T23:00:00Z" # 31.09.23 23:00

# %% [markdown]
# Now we can query and display the data:

# %%
import matplotlib.pyplot as plt

# Define function to read the data for a specific station and a specific time range.
# Returns the data as a Pandas dataframe
def getData(stationName, startTime, endTime):
    #Define the headers to request CSV data as a python dictionary
    headers = {
        "Accept": "text/csv"
    }

    # Read the data
    stationId = stations[stations["name"] == stationName].stationId.values[0]
    # Define the URL including the stationId argument
    url = f"https://smart-urban-heat-map.ch/api/1.0/timeseries?stationId={stationId}&timeFrom={startTime}&timeTo={endTime}"

    # Make the GET request with the headers
    response = requests.get(url, headers=headers)
    return pd.read_csv(io.StringIO(response.text), delimiter=";")

# Read the data for the 3 stations:
stationName1 = "Bundesplatz"
stationName2 = "Marktplatz Lyss"
stationName3 = "Ittigen Papiermühle Kreisel"
timeseries1 = getData(stationName1, startTime, endTime)
timeseries2 = getData(stationName2, startTime, endTime)
timeseries3 = getData(stationName3, startTime, endTime)

# Now plot the data
plt.figure(figsize=(10, 6))


# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
timeseries1.plot(x='dateObserved', y='temperature', label=stationName1, marker=None, color='blue', linestyle='-', ax=plt.gca())
timeseries2.plot(x='dateObserved', y='temperature', label=stationName2, marker=None, color='green', linestyle='-', ax=plt.gca())
timeseries3.plot(x='dateObserved', y='temperature', label=stationName3, marker=None, color='red', linestyle='-', ax=plt.gca())

plt.title('Temperature Curve')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1
#
# Query the relative humidity data for the week from April 1 to April 7 for the following weather stations
# * Sigriswil
# * Westside Center
# * Elfenau
#
# Make sure to use the correct time zone of Switzerland; also Switzerland changed to Daylight Saving Time on March 31, 2024.
#
# Display the data as graph.

# %%
# Your code goes here

# Define the time period
tStart = "2024-03-31T22:00:00Z" # 2024/04/01 00:00 CEST; Z means UTC time
tEnd = "2024-04-07T22:00:00Z"   # 2024/04/07 24:00 CEST

# Query the data for the 3 stations using the function defined above:
exStation1 = "Sigriswil"
exStation2 = "Westside Center"
exStation3 = "Elfenau"
exSeries1 = getData(exStation1, tStart, tEnd)
exSeries2 = getData(exStation2, tStart, tEnd)
exSeries3 = getData(exStation3, tStart, tEnd)

# Now plot the data
plt.figure(figsize=(10, 6))


# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
exSeries1.plot(x='dateObserved', y='relativeHumidity', label=exStation1, marker=None, color='blue', linestyle='-', ax=plt.gca())
exSeries2.plot(x='dateObserved', y='relativeHumidity', label=exStation2, marker=None, color='green', linestyle='-', ax=plt.gca())
exSeries3.plot(x='dateObserved', y='relativeHumidity', label=exStation3, marker=None, color='red', linestyle='-', ax=plt.gca())

plt.title('Relative Humidity Curve')
plt.xlabel('Time')
plt.ylabel('Rel. Humidity (%)')
# Out:
# Text(0, 0.5, 'Rel. Humidity (%)')

# %% [markdown]
# **Expected Result**: If you did everything correctly, the following graph should be displayed:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercise 2
# What was the average temperature in Sigriswil during that week?
#
# Round the results to 2 digits.

# %%
# Your code goes here

# Note: We don't need to requery the data, we can use the data frame from the query before
avgTemp = exSeries1['temperature'].mean()

round(avgTemp, 2)
# Out:
# 13.07

# %% [markdown]
# **Expected Result**: The average temperature was *13.07 °C*.
