# %% [markdown]
# # Simple Example of IoT Programming for the Smart City
#
# This example shows how temperature and humidity data from weather stations in the Bern region can be queried and visualised using simple Python code. This example was developed as part of the __[Smart Urban Heat Map Bern](https://smart-urban-heat-map.ch/)__ project.
#
# It uses a **Web-API** that was defined by [MeteoTest](https://meteotest.ch/en/company/about-us), a Swiss private company that develops and sells data driven services and products in the areas of weather, climate and the environment. It is simple to use, but doesn't conform to any standards like [SensorThings](https://www.ogc.org/standard/sensorthings/) defined by the [Open Geospatial Consortium](https://www.ogc.org/).
#
# API documentation: https://meteotest.github.io/urban-heat-API-docs/Swagger/.

# %% [markdown]
# ## Part 1 - Loading and Displaying Current Data

# %% [markdown]
# ### Step 1: Importing the required Python libraries

# %%
import io # for working with streams (like strings)
import requests # for making standard HTTP requests
import pandas as pd # for storing and manipulating data
import geopandas as gpd # for storing and manipulating geographic data
import folium # for creating maps
import branca # for using colorscales in Folium
import json # for data handling

# %% [markdown]
# ### Step 2: Query list of all weather stations

# %%
# Define the URL
url = "https://smart-urban-heat-map.ch/api/1.0/stations"

# Make the GET request
response = requests.get(url)

# Display the result
print(response.text)
# Out:
# {"type": "FeatureCollection", "features": [{"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.46244, 46.96798]}, "properties": {"stationId": "1E0551FEFF6E959E", "name": "Wankdorf ESP", "dateObserved": "2024-05-28T02:55:36Z", "temperature": 11.258488, "relativeHumidity": 87.81438}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42713, 46.94479]}, "properties": {"stationId": "0940CBFEFFE70FFE", "name": "Kreuzung Brunnmatt-Schwarztorstrasse", "dateObserved": "2024-05-28T02:55:32Z", "temperature": 11.285192, "relativeHumidity": 90.93866}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.47194, 46.95553]}, "properties": {"stationId": "270551FEFF6E959E", "name": "Galgenfeld Industrie", "dateObserved": "2024-05-28T02:55:29Z", "temperature": 10.809873, "relativeHumidity": 95.51827}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.4602, 46.95188]}, "properties": {"stationId": "F5C450FEFF6E959E", "name": "Rosengarten", "dateObserved": "2024-05-28T02:55:08Z", "temperature": 10.190356, "relativeHumidity": 95.96651}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.44361, 46.94826]}, "properties": {"stationId": "1840CBFEFFE70FFE", "name": "B\u00e4renplatz", "dateObserved": "2024-05-28T02:55:02Z", "temperature": 11.458762, "relativeHumidity": 86.719536}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.46407, 46.94714]}, "properties": {"stationId": "1C40CBFEFFE70FFE", "name": "Obstberg, Wattenwylweg 32", "dateObserved": "2024-05-28T02:54:45Z", "temperature": 10.964751, "relativeHumidity": 92.68963}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.50376, 46.96681]}, "properties": {"stationId": "140551FEFF6E959E", "name": "Umland Bolligen", "dateObserved": "2024-05-28T02:54:41Z", "temperature": 10.7057295, "relativeHumidity": 98.43847}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43714, 46.9517]}, "properties": {"stationId": "D53FCBFEFFE70FFE", "name": "L\u00e4nggasse Falkenweg", "dateObserved": "2024-05-28T02:54:28Z", "temperature": 10.46807, "relativeHumidity": 96.26215}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.39587, 46.94302]}, "properties": {"stationId": "0C0551FEFF6E959E", "name": "B\u00fcmpliz St\u00f6ckacker", "dateObserved": "2024-05-28T02:54:27Z", "temperature": 10.337224, "relativeHumidity": 93.96567}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.44513, 46.95898]}, "properties": {"stationId": "EA3FCBFEFFE70FFE", "name": "Lorraine, Steckweg 17", "dateObserved": "2024-05-28T02:54:26Z", "temperature": 11.303884, "relativeHumidity": 91.81415}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43094, 46.94195]}, "properties": {"stationId": "4540CBFEFFE70FFE", "name": "P\u00e4rkli bei Eigerplatz", "dateObserved": "2024-05-28T02:54:12Z", "temperature": 10.978104, "relativeHumidity": 90.4847}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42805, 46.93514]}, "properties": {"stationId": "F4C450FEFF6E959E", "name": "Steinh\u00f6lzliwald", "dateObserved": "2024-05-28T02:54:11Z", "temperature": 9.8378725, "relativeHumidity": 98.59678}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42252, 46.95291]}, "properties": {"stationId": "1740CBFEFFE70FFE", "name": "VonRoll", "dateObserved": "2024-05-28T02:54:05Z", "temperature": 10.521477, "relativeHumidity": 96.32128}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.48201, 46.96241]}, "properties": {"stationId": "6B0551FEFF6E959E", "name": "Ostermundigen Milchstrasse", "dateObserved": "2024-05-28T02:54:01Z", "temperature": 11.375982, "relativeHumidity": 93.7425}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42771, 46.92253]}, "properties": {"stationId": "7ED650FEFF6E959E", "name": "K\u00f6niz Blinzernplateau Strom-/Telefonmast", "dateObserved": "2024-05-28T02:54:00Z", "temperature ...

# %% [markdown]
# Reformatting for better readability:

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46244,
#           46.96798
#         ]
#       },
#       "properties": {
#         "stationId": "1E0551FEFF6E959E",
#         "name": "Wankdorf ESP",
#         "dateObserved": "2024-05-28T02:55:36Z",
#         "temperature": 11.258488,
#         "relativeHumidity": 87.81438
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42713,
#           46.94479
#         ]
#       },
#       "properties": {
#         "stationId": "0940CBFEFFE70FFE",
#         "name": "Kreuzung Brunnmatt-Schwarztorstrasse",
#         "dateObserved": "2024-05-28T02:55:32Z",
#         "temperature": 11.285192,
#         "relativeHumidity": 90.93866
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47194,
#           46.95553
#         ]
#       },
#       "properties": {
#         "stationId": "270551FEFF6E959E",
#         "name": "Galgenfeld Industrie",
#         "dateObserved": "2024-05-28T02:55:29Z",
#         "temperature": 10.809873,
#         "relativeHumidity": 95.51827
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4602,
#           46.95188
#         ]
#       },
#       "properties": {
#         "stationId": "F5C450FEFF6E959E",
#         "name": "Rosengarten",
#         "dateObserved": "2024-05-28T02:55:08Z",
#         "temperature": 10.190356,
#         "relativeHumidity": 95.96651
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44361,
#           46.94826
#         ]
#       },
#       "properties": {
#         "stationId": "1840CBFEFFE70FFE",
#         "name": "B\u00e4renplatz",
#         "dateObserved": "2024-05-28T02:55:02Z",
#         "temperature": 11.458762,
#         "relativeHumidity": 86.719536
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46407,
#           46.94714
#         ]
#       },
#       "properties": {
#         "stationId": "1C40CBFEFFE70FFE",
#         "name": "Obstberg, Wattenwylweg 32",
#         "dateObserved": "2024-05-28T02:54:45Z",
#         "temperature": 10.964751,
#         "relativeHumidity": 92.68963
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50376,
#           46.96681
#         ]
#       },
#       "properties": {
#         "stationId": "140551FEFF6E959E",
#         "name": "Umland Bolligen",
#         "dateObserved": "2024-05-28T02:54:41Z",
#         "temperature": 10.7057295,
#         "relativeHumidity": 98.43847
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43714,
#           46.9517
#         ]
#       },
#       "properties": {
#         "stationId": "D53FCBFEFFE70FFE",
#         "name": "L\u00e4nggasse Falkenweg",
#         "dateObserved": "2024-05-28T02:54:28Z",
#         "temperature": 10.46807,
#         "relativeHumidity": 96.26215
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.39587,
#           46.94302
#         ]
#       },
#       "properties": {
#         "stationId": "0C0551FEFF6E959E",
#         "name": "B\u00fcmpliz St\u00f6ckacker",
#         "dateObserved": "2024-05-28T02:54:27Z",
#         "temperature": 10.337224,
#         "relativeHumidity": 93.96567
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44513,
#           46.95898
#         ]
#       },
#       "properties": {
#         "stationId": "EA3FCBFEFFE70FFE",
#         "name": "Lorraine, Steckweg 17",
#         "dateObserved": "2024-05-28T02:54:26Z",
#         "temperature": 11.303884,
#         "relativeHumidity": 91.81415
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43094,
#           46.94195
#         ]
#       },
#       "properties": {
#         "stationId": "4540CBFEFFE70FFE",
#         "name": "P\u00e4rkli bei Eigerplatz",
#         "dateObserved": "2024-05-28T02:54:12Z",
#         "temperature": 10.978104,
#         "relativeHumidity": 90.4847
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42805,
#           46.93514
#         ]
#       },
#       "properties": {
#         "stationId": "F4C450FEFF6E959E",
#         "name": "Steinh\u00f6lzliwald",
#         "dateObserved": "2024-05-28T02:54:11Z",
#         "temperature": 9.8378725,
#         "relativeHumidity": 98.59678
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42252,
#           46.95291
#         ]
#       },
#       "properties": {
#         "stationId": "1740CBFEFFE70FFE",
#         "name": "VonRoll",
#         "dateObserved": "2024-05-28T02:54:05Z",
#         "temperature": 10.521477,
#         "relativeHumidity": 96.32128
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48201,
#           46.96241
#         ]
#       },
#       "properties": {
#         "stationId": "6B0551FEFF6E959E",
#         "name": "Ostermundigen Milchstrasse",
#         "dateObserved": "2024-05-28T02:54:01Z",
#         "temperature": 11.375982,
#         "relativeHumidity": 93.7425
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42771,
#           46.92253
#         ]
#       },
#       "properties": {
#         "stationId": "7ED650FEFF6E959E",
#         "name": "K\u00f6niz Blinzernplateau Strom-/Telefonmast",
#         "dateObserved": "2024-05-28T02:54:00Z",
#         "temperature": 9.642939,
#         "relativeHumidity": 87.75525
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45586,
#           46.94701
#         ]
#       },
#       "properties": {
#         "stationId": "1F40CBFEFFE70FFE",
#         "name": "Matte M\u00fchleplatz",
#         "dateObserved": "2024-05-28T02:53:57Z",
#         "temperature": 11.213092,
#         "relativeHumidity": 96.7905
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46146,
#           46.96017
#         ]
#       },
#       "properties": {
#         "stationId": "D43FCBFEFFE70FFE",
#         "name": "Tellstrasse",
#         "dateObserved": "2024-05-28T02:53:54Z",
#         "temperature": 10.959411,
#         "relativeHumidity": 92.97383
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49879,
#           46.95566
#         ]
#       },
#       "properties": {
#         "stationId": "D40451FEFF6E959E",
#         "name": "Ostermundigen Ahornstrasse 16",
#         "dateObserved": "2024-05-28T02:53:47Z",
#         "temperature": 10.71107,
#         "relativeHumidity": 96.83627
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.30584,
#           47.073505
#         ]
#       },
#       "properties": {
#         "stationId": "59E350FEFF6E959E",
#         "name": "Marktplatz Lyss",
#         "dateObserved": "2024-05-28T02:53:42Z",
#         "temperature": 10.86862,
#         "relativeHumidity": 87.94789
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.299204,
#           47.071545
#         ]
#       },
#       "properties": {
#         "stationId": "7DE350FEFF6E959E",
#         "name": "Spielplatz Stiglimatt",
#         "dateObserved": "2024-05-28T02:53:28Z",
#         "temperature": 10.609598,
#         "relativeHumidity": 82.37263
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.51184,
#           46.89942
#         ]
#       },
#       "properties": {
#         "stationId": "4840CBFEFFE70FFE",
#         "name": "Umland Belp",
#         "dateObserved": "2024-05-28T02:53:26Z",
#         "temperature": 10.825894,
#         "relativeHumidity": 97.43137
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.386227,
#           46.928032
#         ]
#       },
#       "properties": {
#         "stationId": "10D850FEFF6E959E",
#         "name": "Niederwangen Papillon Laterne/Bush\u00e4uschen",
#         "dateObserved": "2024-05-28T02:53:19Z",
#         "temperature": 9.90196,
#         "relativeHumidity": 88.48196
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44009,
#           46.96286
#         ]
#       },
#       "properties": {
#         "stationId": "450551FEFF6E959E",
#         "name": "Viererfeld 3 (Strasse S\u00fcd)",
#         "dateObserved": "2024-05-28T02:53:17Z",
#         "temperature": 10.275806,
#         "relativeHumidity": 96.07713
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45045,
#           46.95597
#         ]
#       },
#       "properties": {
#         "stationId": "350551FEFF6E959E",
#         "name": "Optingenstrasse",
#         "dateObserved": "2024-05-28T02:53:09Z",
#         "temperature": 11.068894,
#         "relativeHumidity": 90.13565
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45192,
#           46.96173
#         ]
#       },
#       "properties": {
#         "stationId": "0240CBFEFFE70FFE",
#         "name": "Breitenrain, Waffenweg",
#         "dateObserved": "2024-05-28T02:53:05Z",
#         "temperature": 11.012817,
#         "relativeHumidity": 91.75502
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42317,
#           46.93716
#         ]
#       },
#       "properties": {
#         "stationId": "2340CBFEFFE70FFE",
#         "name": "Eisenbahnquartier",
#         "dateObserved": "2024-05-28T02:52:55Z",
#         "temperature": 10.529488,
#         "relativeHumidity": 93.6643
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "230551FEFF6E959E",
#         "name": "Gurten Kulm 2",
#         "dateObserved": "2024-05-28T02:52:53Z",
#         "temperature": 11.162356,
#         "relativeHumidity": 92.35584
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.489671,
#           46.971962
#         ]
#       },
#       "properties": {
#         "stationId": "E2E250FEFF6E959E",
#         "name": "Ittigen Worblentalstrasse",
#         "dateObserved": "2024-05-28T02:52:52Z",
#         "temperature": 11.426719,
#         "relativeHumidity": 90.45228
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.456929,
#           46.99266
#         ]
#       },
#       "properties": {
#         "stationId": "5FE350FEFF6E959E",
#         "name": "Zollikofen Zentrum Laterne",
#         "dateObserved": "2024-05-28T02:52:51Z",
#         "temperature": 11.082246,
#         "relativeHumidity": 87.69611
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.477217,
#           46.974644
#         ]
#       },
#       "properties": {
#         "stationId": "95D650FEFF6E959E",
#         "name": "Ittigen Papierm\u00fchle Kreisel",
#         "dateObserved": "2024-05-28T02:52:50Z",
#         "temperature": 13.429465,
#         "relativeHumidity": 79.61074
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44353,
#           46.94692
#         ]
#       },
#       "properties": {
#         "stationId": "0140CBFEFFE70FFE",
#         "name": "Bundesplatz",
#         "dateObserved": "2024-05-28T02:52:47Z",
#         "temperature": 11.19173,
#         "relativeHumidity": 87.980316
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48114,
#           46.95563
#         ]
#       },
#       "properties": {
#         "stationId": "D60451FEFF6E959E",
#         "name": "Ostermundigen B\u00e4reTower",
#         "dateObserved": "2024-05-28T02:52:45Z",
#         "temperature": 11.35462,
#         "relativeHumidity": 93.4564
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.484087,
#           46.947945
#         ]
#       },
#       "properties": {
#         "stationId": "1A40CBFEFFE70FFE",
#         "name": "Ostermundigen Tiefenm\u00f6sli",
#         "dateObserved": "2024-05-28T02:52:42Z",
#         "temperature": 11.095598,
#         "relativeHumidity": 97.00984
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50045,
#           46.93537
#         ]
#       },
#       "properties": {
#         "stationId": "FBDD50FEFF6E959E",
#         "name": "G\u00fcmligen (Worbstrasse) Laterne",
#         "dateObserved": "2024-05-28T02:52:33Z",
#         "temperature": 11.002136,
#         "relativeHumidity": 89.529106
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.310936,
#           47.075108
#         ]
#       },
#       "properties": {
#         "stationId": "3DD650FEFF6E959E",
#         "name": "Heilbachweg | Oberfeldweg",
#         "dateObserved": "2024-05-28T02:52:33Z",
#         "temperature": 10.46807,
#         "relativeHumidity": 86.81491
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48222,
#           46.95867
#         ]
#       },
#       "properties": {
#         "stationId": "460551FEFF6E959E",
#         "name": "Ostermundigen Poststrasse 2",
#         "dateObserved": "2024-05-28T02:52:31Z",
#         "temperature": 11.167697,
#         "relativeHumidity": 94.76486
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47992,
#           46.93919
#         ]
#       },
#       "properties": {
#         "stationId": "320551FEFF6E959E",
#         "name": "Murifeld",
#         "dateObserved": "2024-05-28T02:52:27Z",
#         "temperature": 10.9300375,
#         "relativeHumidity": 96.34417
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47186,
#           46.95339
#         ]
#       },
#       "properties": {
#         "stationId": "060551FEFF6E959E",
#         "name": "Schosshaldenfriedhof 2",
#         "dateObserved": "2024-05-28T02:52:25Z",
#         "temperature": 9.920653,
#         "relativeHumidity": 93.33051
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37708,
#           46.94787
#         ]
#       },
#       "properties": {
#         "stationId": "0840CBFEFFE70FFE",
#         "name": "Ansermetplatz",
#         "dateObserved": "2024-05-28T02:52:23Z",
#         "temperature": 10.668345,
#         "relativeHumidity": 94.25941
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.480363,
#           46.957783
#         ]
#       },
#       "properties": {
#         "stationId": "0B0551FEFF6E959E",
#         "name": "Ostermundigen Schermenweg",
#         "dateObserved": "2024-05-28T02:52:15Z",
#         "temperature": 11.253147,
#         "relativeHumidity": 95.93408
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45656,
#           46.93798
#         ]
#       },
#       "properties": {
#         "stationId": "D03FCBFEFFE70FFE",
#         "name": "D\u00e4hlh\u00f6lzliwald",
#         "dateObserved": "2024-05-28T02:52:05Z",
#         "temperature": 10.206378,
#         "relativeHumidity": 101.63523
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48719,
#           46.95309
#         ]
#       },
#       "properties": {
#         "stationId": "1D40CBFEFFE70FFE",
#         "name": "Ostermundigen L\u00f6tschenstrasse 13",
#         "dateObserved": "2024-05-28T02:51:56Z",
#         "temperature": 11.103609,
#         "relativeHumidity": 94.46349
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46442,
#           46.94469
#         ]
#       },
#       "properties": {
#         "stationId": "090551FEFF6E959E",
#         "name": "Egelsee",
#         "dateObserved": "2024-05-28T02:51:55Z",
#         "temperature": 10.660335,
#         "relativeHumidity": 97.000305
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.490017,
#           46.980637
#         ]
#       },
#       "properties": {
#         "stationId": "C0C450FEFF6E959E",
#         "name": "Ittigen Gantrischweg 1 Laterne",
#         "dateObserved": "2024-05-28T02:51:53Z",
#         "temperature": 10.476082,
#         "relativeHumidity": 90.061264
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45351,
#           46.9481
#         ]
#       },
#       "properties": {
#         "stationId": "E4C450FEFF6E959E",
#         "name": "Gerechtigkeitsgasse",
#         "dateObserved": "2024-05-28T02:51:52Z",
#         "temperature": 12.086289,
#         "relativeHumidity": 84.167465
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40633,
#           46.94333
#         ]
#       },
#       "properties": {
#         "stationId": "2F40CBFEFFE70FFE",
#         "name": "Europaplatz 2",
#         "dateObserved": "2024-05-28T02:51:49Z",
#         "temperature": 10.745785,
#         "relativeHumidity": 90.51713
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.481124,
#           46.926167
#         ]
#       },
#       "properties": {
#         "stationId": "61E350FEFF6E959E",
#         "name": "Muri Bl\u00fcmlisalpstrasse",
#         "dateObserved": "2024-05-28T02:51:49Z",
#         "temperature": 10.860609,
#         "relativeHumidity": 89.336464
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45824,
#           46.94059
#         ]
#       },
#       "properties": {
#         "stationId": "0A40CBFEFFE70FFE",
#         "name": "Thunplatz",
#         "dateObserved": "2024-05-28T02:51:41Z",
#         "temperature": 10.652323,
#         "relativeHumidity": 95.94362
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.319325,
#           47.098705
#         ]
#       },
#       "properties": {
#         "stationId": "A4E250FEFF6E959E",
#         "name": "Bahnhofplatz Busswil",
#         "dateObserved": "2024-05-28T02:51:39Z",
#         "temperature": 10.801862,
#         "relativeHumidity": 83.600975
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.471829,
#           46.94506
#         ]
#       },
#       "properties": {
#         "stationId": "B9C450FEFF6E959E",
#         "name": "Bern-Ostring Freudenbergplatz Laterne",
#         "dateObserved": "2024-05-28T02:51:29Z",
#         "temperature": 11.314565,
#         "relativeHumidity": 87.57786
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.498633,
#           46.892506
#         ]
#       },
#       "properties": {
#         "stationId": "30E450FEFF6E959E",
#         "name": "Belp Zentrum Laterne",
#         "dateObserved": "2024-05-28T02:51:26Z",
#         "temperature": 10.86862,
#         "relativeHumidity": 84.676735
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43541,
#           46.95789
#         ]
#       },
#       "properties": {
#         "stationId": "CD3FCBFEFFE70FFE",
#         "name": "Hintere L\u00e4nggasse",
#         "dateObserved": "2024-05-28T02:51:18Z",
#         "temperature": 10.897993,
#         "relativeHumidity": 92.43214
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46747,
#           46.9645
#         ]
#       },
#       "properties": {
#         "stationId": "E4EA50FEFF6E959E",
#         "name": "Bern Wankdorfplatz Laterne",
#         "dateObserved": "2024-05-28T02:51:15Z",
#         "temperature": 11.4374,
#         "relativeHumidity": 86.10918
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4133654,
#           46.938255
#         ]
#       },
#       "properties": {
#         "stationId": "D7DD50FEFF6E959E",
#         "name": "Liebefeld Turnierstrasse Laterne",
#         "dateObserved": "2024-05-28T02:51:13Z",
#         "temperature": 9.891279,
#         "relativeHumidity": 91.230484
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45326,
#           46.93122
#         ]
#       },
#       "properties": {
#         "stationId": "3740CBFEFFE70FFE",
#         "name": "Wabern Viktoriastrasse",
#         "dateObserved": "2024-05-28T02:51:07Z",
#         "temperature": 10.585565,
#         "relativeHumidity": 95.72045
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41688,
#           46.94211
#         ]
#       },
#       "properties": {
#         "stationId": "1140CBFEFFE70FFE",
#         "name": "Schlossmatte Familieng\u00e4rten",
#         "dateObserved": "2024-05-28T02:51:04Z",
#         "temperature": 10.070191,
#         "relativeHumidity": 98.226746
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42946,
#           46.94672
#         ]
#       },
#       "properties": {
#         "stationId": "9FD350FEFF6E959E",
#         "name": "Emch+Berger (Schl\u00f6sslistrasse) Pfosten Eingang",
#         "dateObserved": "2024-05-28T02:51:03Z",
#         "temperature": 11.338597,
#         "relativeHumidity": 80.57969
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48807,
#           46.95813
#         ]
#       },
#       "properties": {
#         "stationId": "0F40CBFEFFE70FFE",
#         "name": "Ostermuniugen Moosweg",
#         "dateObserved": "2024-05-28T02:51:01Z",
#         "temperature": 11.151674,
#         "relativeHumidity": 95.415276
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4285746,
#           46.95617
#         ]
#       },
#       "properties": {
#         "stationId": "593FCBFEFFE70FFE",
#         "name": "Bern Hintere L\u00e4nggasse",
#         "dateObserved": "2024-05-28T02:50:58Z",
#         "temperature": 10.775158,
#         "relativeHumidity": 84.51461
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48214,
#           46.95869
#         ]
#       },
#       "properties": {
#         "stationId": "2840CBFEFFE70FFE",
#         "name": "Ostermundigen Poststrasse",
#         "dateObserved": "2024-05-28T02:50:47Z",
#         "temperature": 10.820554,
#         "relativeHumidity": 94.74006
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.712437,
#           46.713448
#         ]
#       },
#       "properties": {
#         "stationId": "4640CBFEFFE70FFE",
#         "name": "Sigriswil",
#         "dateObserved": "2024-05-28T02:50:39Z",
#         "temperature": 9.8191805,
#         "relativeHumidity": 87.69421
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45802,
#           46.95696
#         ]
#       },
#       "properties": {
#         "stationId": "4940CBFEFFE70FFE",
#         "name": "Kasernenareal",
#         "dateObserved": "2024-05-28T02:50:32Z",
#         "temperature": 10.828565,
#         "relativeHumidity": 91.91333
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4695,
#           46.93558
#         ]
#       },
#       "properties": {
#         "stationId": "1E40CBFEFFE70FFE",
#         "name": "Elfenau",
#         "dateObserved": "2024-05-28T02:50:27Z",
#         "temperature": 10.820554,
#         "relativeHumidity": 96.98886
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43462,
#           46.94187
#         ]
#       },
#       "properties": {
#         "stationId": "0640CBFEFFE70FFE",
#         "name": "Monbijou-Park",
#         "dateObserved": "2024-05-28T02:50:27Z",
#         "temperature": 10.457389,
#         "relativeHumidity": 95.34089
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45935,
#           46.92921
#         ]
#       },
#       "properties": {
#         "stationId": "17D950FEFF6E959E",
#         "name": "Wabern Weyergut",
#         "dateObserved": "2024-05-28T02:50:21Z",
#         "temperature": 10.777828,
#         "relativeHumidity": 86.29229
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45978,
#           46.97857
#         ]
#       },
#       "properties": {
#         "stationId": "1EDE50FEFF6E959E",
#         "name": "Ittigen Worblaufenstrasse  Laterne",
#         "dateObserved": "2024-05-28T02:50:15Z",
#         "temperature": 11.034181,
#         "relativeHumidity": 88.182495
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4540253,
#           46.958252
#         ]
#       },
#       "properties": {
#         "stationId": "1540CBFEFFE70FFE",
#         "name": "Breitenrainplatz 127",
#         "dateObserved": "2024-05-28T02:50:12Z",
#         "temperature": 11.10895,
#         "relativeHumidity": 90.88335
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43688,
#           46.96271
#         ]
#       },
#       "properties": {
#         "stationId": "1240CBFEFFE70FFE",
#         "name": "Viererfeld 2 (Schacht)",
#         "dateObserved": "2024-05-28T02:50:10Z",
#         "temperature": 10.014114,
#         "relativeHumidity": 96.3785
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.525039,
#           46.9585
#         ]
#       },
#       "properties": {
#         "stationId": "2BD650FEFF6E959E",
#         "name": "Stettlen Bernstrasse Laterne",
#         "dateObserved": "2024-05-28T02:50:04Z",
#         "temperature": 11.691081,
#         "relativeHumidity": 86.790115
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46407,
#           46.99079
#         ]
#       },
#       "properties": {
#         "stationId": "3B40CBFEFFE70FFE",
#         "name": "Zollikofen 3m",
#         "dateObserved": "2024-05-28T02:50:01Z",
#         "temperature": 10.732433,
#         "relativeHumidity": 98.40414
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.451387,
#           46.99095
#         ]
#       },
#       "properties": {
#         "stationId": "40DE50FEFF6E959E",
#         "name": "Zollikofen Reichenbach Laterne",
#         "dateObserved": "2024-05-28T02:49:37Z",
#         "temperature": 10.889982,
#         "relativeHumidity": 89.645454
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44007,
#           46.93354
#         ]
#       },
#       "properties": {
#         "stationId": "11D450FEFF6E959E",
#         "name": "Morillongut (Sch\u00f6negg) Mast",
#         "dateObserved": "2024-05-28T02:49:32Z",
#         "temperature": 10.337224,
#         "relativeHumidity": 90.06317
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44122,
#           46.97417
#         ]
#       },
#       "properties": {
#         "stationId": "D83FCBFEFFE70FFE",
#         "name": "Felsenhaldeweg",
#         "dateObserved": "2024-05-28T02:49:27Z",
#         "temperature": 10.743114,
#         "relativeHumidity": 95.76814
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.448146,
#           46.93012
#         ]
#       },
#       "properties": {
#         "stationId": "B8D350FEFF6E959E",
#         "name": "Wabern Zentrum Laterne",
#         "dateObserved": "2024-05-28T02:49:23Z",
#         "temperature": 10.494774,
#         "relativeHumidity": 85.800186
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40995,
#           46.92041
#         ]
#       },
#       "properties": {
#         "stationId": "0A0551FEFF6E959E",
#         "name": "K\u00f6niz Aussenquartier",
#         "dateObserved": "2024-05-28T02:49:23Z",
#         "temperature": 10.14496,
#         "relativeHumidity": 95.358055
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42571,
#           46.94719
#         ]
#       },
#       "properties": {
#         "stationId": "DA0451FEFF6E959E",
#         "name": "Inselspital",
#         "dateObserved": "2024-05-28T02:49:16Z",
#         "temperature": 12.094301,
#         "relativeHumidity": 86.605095
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44571,
#           46.94445
#         ]
#       },
#       "properties": {
#         "stationId": "E40451FEFF6E959E",
#         "name": "Dalmazibr\u00fccke",
#         "dateObserved": "2024-05-28T02:49:12Z",
#         "temperature": 11.140993,
#         "relativeHumidity": 93.81499
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "100551FEFF6E959E",
#         "name": "Gurten Kulm",
#         "dateObserved": "2024-05-28T02:49:10Z",
#         "temperature": 7.995346,
#         "relativeHumidity": 96.599754
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41453,
#           46.92282
#         ]
#       },
#       "properties": {
#         "stationId": "FED550FEFF6E959E",
#         "name": "K\u00f6niz Bl\u00e4uacker Park Aldi/Swisscom",
#         "dateObserved": "2024-05-28T02:49:05Z",
#         "temperature": 10.131609,
#         "relativeHumidity": 88.85962
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.377091,
#           46.92567
#         ]
#       },
#       "properties": {
#         "stationId": "76DA50FEFF6E959E",
#         "name": "Niederwangen Zentrum Laterne",
#         "dateObserved": "2024-05-28T02:49:04Z",
#         "temperature": 9.888609,
#         "relativeHumidity": 89.30595
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.305877,
#           47.07661
#         ]
#       },
#       "properties": {
#         "stationId": "64E350FEFF6E959E",
#         "name": "Monopoliplatz Lyss",
#         "dateObserved": "2024-05-28T02:49:03Z",
#         "temperature": 10.916686,
#         "relativeHumidity": 81.1767
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44773,
#           46.95518
#         ]
#       },
#       "properties": {
#         "stationId": "130551FEFF6E959E",
#         "name": "Viktoriarain",
#         "dateObserved": "2024-05-28T02:48:58Z",
#         "temperature": 11.186389,
#         "relativeHumidity": 90.663994
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.415169,
#           46.90915
#         ]
#       },
#       "properties": {
#         "stationId": "8CDE50FEFF6E959E",
#         "name": "K\u00f6niz Schliern Laterne",
#         "dateObserved": "2024-05-28T02:48:47Z",
#         "temperature": 9.498741,
#         "relativeHumidity": 89.27543
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49371,
#           46.95806
#         ]
#       },
#       "properties": {
#         "stationId": "280551FEFF6E959E",
#         "name": "Ostermundigen Wegm\u00fchleng\u00e4ssli",
#         "dateObserved": "2024-05-28T02:48:46Z",
#         "temperature": 11.138323,
#         "relativeHumidity": 96.296486
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37478,
#           46.94555
#         ]
#       },
#       "properties": {
#         "stationId": "E00451FEFF6E959E",
#         "name": "Westside Center",
#         "dateObserved": "2024-05-28T02:48:44Z",
#         "temperature": 10.580224,
#         "relativeHumidity": 95.537346
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46257,
#           46.96311
#         ]
#       },
#       "properties": {
#         "stationId": "3340CBFEFFE70FFE",
#         "name": "Stadtlabor",
#         "dateObserved": "2024-05-28T02:48:38Z",
#         "temperature": 10.777828,
#         "relativeHumidity": 93.21797
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43786,
#           46.94658
#         ]
#       },
#       "properties": {
#         "stationId": "ED3FCBFEFFE70FFE",
#         "name": "Hirschengraben",
#         "dateObserved": "2024-05-28T02:48:33Z",
#         "temperature": 11.349279,
#         "relativeHumidity": 87.05142
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.308954,
#           47.0709
#         ]
#       },
#       "properties": {
#         "stationId": "24E350FEFF6E959E",
#         "name": "M\u00fchleplatz Lyss",
#         "dateObserved": "2024-05-28T02:48:33Z",
#         "temperature": 10.470741,
#         "relativeHumidity": 85.47402
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40134,
#           46.949
#         ]
#       },
#       "properties": {
#         "stationId": "C33FCBFEFFE70FFE",
#         "name": "Weyermannshaus Industrie 2",
#         "dateObserved": "2024-05-28T02:48:30Z",
#         "temperature": 10.425345,
#         "relativeHumidity": 95.20737
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44082,
#           46.95151
#         ]
#       },
#       "properties": {
#         "stationId": "0F0551FEFF6E959E",
#         "name": "Bollwerk Strasseninsel",
#         "dateObserved": "2024-05-28T02:48:30Z",
#         "temperature": 11.824597,
#         "relativeHumidity": 89.09422
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.481412,
#           46.94348
#         ]
#       },
#       "properties": {
#         "stationId": "5AE350FEFF6E959E",
#         "name": "Bern Merzenacker",
#         "dateObserved": "2024-05-28T02:48:22Z",
#         "temperature": 10.900663,
#         "relativeHumidity": 86.633705
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49792,
#           46.9581
#         ]
#       },
#       "properties": {
#         "stationId": "020551FEFF6E959E",
#         "name": "Ostermundigen Oberfeld",
#         "dateObserved": "2024-05-28T02:48:16Z",
#         "temperature": 10.87129,
#         "relativeHumidity": 95.035706
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43739,
#           46.92607
#         ]
#       },
#       "properties": {
#         "stationId": "200551FEFF6E959E",
#         "name": "Spiegel",
#         "dateObserved": "2024-05-28T02:48:15Z",
#         "temperature": 9.864576,
#         "relativeHumidity": 92.00679
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.301668,
#           47.077145
#         ]
#       },
#       "properties": {
#         "stationId": "E3E250FEFF6E959E",
#         "name": "Reitplatz Gr\u00fcnau",
#         "dateObserved": "2024-05-28T02:48:14Z",
#         "temperature": 10.502785,
#         "relativeHumidity": 88.337
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44894,
#           46.94391
#         ]
#       },
#       "properties": {
#         "stationId": "EB3FCBFEFFE70FFE",
#         "name": "Helvetiaplatz neu",
#         "dateObserved": "2024-05-28T02:48:08Z",
#         "temperature": 11.103609,
#         "relativeHumidity": 92.61906
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46987,
#           46.95063
#         ]
#       },
#       "properties": {
#         "stationId": "410551FEFF6E959E",
#         "name": "Galgenfeld Neubausiedlung",
#         "dateObserved": "2024-05-28T02:47:59Z",
#         "temperature": 10.972763,
#         "relativeHumidity": 97.19867
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42015,
#           46.9503
#         ]
#       },
#       "properties": {
#         "stationId": "1440CBFEFFE70FFE",
#         "name": "Bremgartenfriedhof",
#         "dateObserved": "2024-05-28T02:47:54Z",
#         "temperature": 10.227741,
#         "relativeHumidity": 96.67223
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40896,
#           46.92981
#         ]
#       },
#       "properties": {
#         "stationId": "62E350FEFF6E959E",
#         "name": "K\u00f6niz Gartenstadt Laterne",
#         "dateObserved": "2024-05-28T02:47:46Z",
#         "temperature": 9.757763,
#         "relativeHumidity": 90.27871
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50944,
#           46.9377
#         ]
#       },
#       "properties": {
#         "stationId": "B3C450FEFF6E959E",
#         "name": "G\u00fcmligen Dentenberg Laterne",
#         "dateObserved": "2024-05-28T02:47:44Z",
#         "temperature": 10.473412,
#         "relativeHumidity": 91.8008
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.445022,
#           46.95565
#         ]
#       },
#       "properties": {
#         "stationId": "A9E450FEFF6E959E",
#         "name": "Bern Lorrainepark",
#         "dateObserved": "2024-05-28T02:47:43Z",
#         "temperature": 11.055543,
#         "relativeHumidity": 81.63256
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4986053,
#           46.92633
#         ]
#       },
#       "properties": {
#         "stationId": "B7D350FEFF6E959E",
#         "name": "Muri Steinh\u00fcbeliweg",
#         "dateObserved": "2024-05-28T02:47:40Z",
#         "temperature": 10.847258,
#         "relativeHumidity": 87.16586
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42031,
#           46.92781
#         ]
#       },
#       "properties": {
#         "stationId": "2C40CBFEFFE70FFE",
#         "name": "K\u00f6niz Neubausiedlung",
#         "dateObserved": "2024-05-28T02:47:27Z",
#         "temperature": 10.112917,
#         "relativeHumidity": 94.921265
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48628,
#           46.93048
#         ]
#       },
#       "properties": {
#         "stationId": "693FCBFEFFE70FFE",
#         "name": "Muri Zentrum (Tavelweg) Laterne",
#         "dateObserved": "2024-05-28T02:47:18Z",
#         "temperature": 11.026169,
#         "relativeHumidity": 88.50294
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4377694,
#           46.938946
#         ]
#       },
#       "properties": {
#         "stationId": "D4C050FEFF6E959E",
#         "name": "Bern Sulgenau",
#         "dateObserved": "2024-05-28T02:47:01Z",
#         "temperature": 11.002136,
#         "relativeHumidity": 86.875946
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.464513,
#           46.90957
#         ]
#       },
#       "properties": {
#         "stationId": "E8E450FEFF6E959E",
#         "name": "Kehrsatz Breit\u00e4gertenstrasse Laterne",
#         "dateObserved": "2024-05-28T02:46:58Z",
#         "temperature": 9.685664,
#         "relativeHumidity": 86.22171
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40642,
#           46.94542
#         ]
#       },
#       "properties": {
#         "stationId": "010551FEFF6E959E",
#         "name": "Ausserholligen 2, ewb",
#         "dateObserved": "2024-05-28T02:46:57Z",
#         "temperature": 10.727093,
#         "relativeHumidity": 94.03052
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.455911,
#           46.92579
#         ]
#       },
#       "properties": {
#         "stationId": "E7E450FEFF6E959E",
#         "name": "Wabern Gartentower Laterne",
#         "dateObserved": "2024-05-28T02:46:45Z",
#         "temperature": 10.681697,
#         "relativeHumidity": 84.526054
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44165,
#           46.96523
#         ]
#       },
#       "properties": {
#         "stationId": "1040CBFEFFE70FFE",
#         "name": "Viererfeld 4 (Strasse Nord)",
#         "dateObserved": "2024-05-28T02:46:36Z",
#         "temperature": 10.62562,
#         "relativeHumidity": 93.64904
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.5102544,
#           47.01997
#         ]
#       },
#       "properties": {
#         "stationId": "2940CBFEFFE70FFE",
#         "name": "Urtenen-Sch\u00f6nb\u00fchl (3322)",
#         "dateObserved": "2024-05-28T02:46:26Z",
#         "temperature": 11.047532,
#         "relativeHumidity": 92.12314
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41466,
#           46.92327
#         ]
#       },
#       "properties": {
#         "stationId": "FCE350FEFF6E959E",
#         "name": "K\u00f6niz Bl\u00e4uacker Kandelaber auf Platz  ",
#         "dateObserved": "2024-05-28T02:46:16Z",
#         "temperature": 10.294499,
#         "relativeHumidity": 86.82445
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43639,
#           46.94734
#         ]
#       },
#       "properties": {
#         "stationId": "3940CBFEFFE70FFE",
#         "name": "Laupenstrasse",
#         "dateObserved": "2024-05-28T02:46:12Z",
#         "temperature": 11.322576,
#         "relativeHumidity": 87.77432
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.438822,
#           46.977913
#         ]
#       },
#       "properties": {
#         "stationId": "57D550FEFF6E959E",
#         "name": "Bremgarten Ecke Lindenstrasse / Ritterstrasse Laterne",
#         "dateObserved": "2024-05-28T02:46:12Z",
#         "temperature": 10.970093,
#         "relativeHumidity": 88.96643
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43843,
#           46.94728
#         ]
#       },
#       "properties": {
#         "stationId": "FE3FCBFEFFE70FFE",
#         "name": "Bubenbergplatz",
#         "dateObserved": "2024-05-28T02:46:12Z",
#         "temperature": 11.378653,
#         "relativeHumidity": 86.80919
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.392484,
#           46.951385
#         ]
#       },
#       "properties": {
#         "stationId": "12E350FEFF6E959E",
#         "name": "Bern Bethlehem Laterne",
#         "dateObserved": "2024-05-28T02:46:11Z",
#         "temperature": 10.636301,
#         "relativeHumidity": 87.96506
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.470893,
#           46.90922
#         ]
#       },
#       "properties": {
#         "stationId": "11E350FEFF6E959E",
#         "name": "Kehrsatz Zentrum Laterne",
#         "dateObserved": "2024-05-28T02:46:08Z",
#         "temperature": 9.907302,
#         "relativeHumidity": 89.71603
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.497151,
#           46.975468
#         ]
#       },
#       "properties": {
#         "stationId": "C9EA50FEFF6E959E",
#         "name": "Bolligen Sternenkreisel Laterne",
#         "dateObserved": "2024-05-28T02:46:03Z",
#         "temperature": 11.317235,
#         "relativeHumidity": 87.85062
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "190551FEFF6E959E",
#         "name": "Gurten Kulm 3",
#         "dateObserved": "2024-05-28T02:46:01Z",
#         "temperature": 10.582894,
#         "relativeHumidity": 93.837875
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.311275,
#           47.078552
#         ]
#       },
#       "properties": {
#         "stationId": "2FE450FEFF6E959E",
#         "name": "Schulhaus Grentschel",
#         "dateObserved": "2024-05-28T02:45:56Z",
#         "temperature": 10.390631,
#         "relativeHumidity": 84.50317
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42128,
#           46.96512
#         ]
#       },
#       "properties": {
#         "stationId": "C03FCBFEFFE70FFE",
#         "name": "Bremgartenwald",
#         "dateObserved": "2024-05-28T02:45:50Z",
#         "temperature": 10.377279,
#         "relativeHumidity": 97.459984
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43141,
#           46.94067
#         ]
#       },
#       "properties": {
#         "stationId": "3A0551FEFF6E959E",
#         "name": "Eigerplatz",
#         "dateObserved": "2024-05-28T02:45:48Z",
#         "temperature": 11.039521,
#         "relativeHumidity": 90.39315
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46247,
#           46.968
#         ]
#       },
#       "properties": {
#         "stationId": "ECC450FEFF6E959E",
#         "name": "Wankdorf ESP 2",
#         "dateObserved": "2024-05-28T02:45:44Z",
#         "temperature": 11.287862,
#         "relativeHumidity": 89.71412
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44248,
#           46.90961
#         ]
#       },
#       "properties": {
#         "stationId": "4B40CBFEFFE70FFE",
#         "name": "K\u00f6niztal",
#         "dateObserved": "2024-05-28T02:41:20Z",
#         "temperature": 9.127565,
#         "relativeHumidity": 99.29107
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37676,
#           46.96736
#         ]
#       },
#       "properties": {
#         "stationId": "7FEA50FEFF6E959E",
#         "name": "Wohlen Hinterkappelenring Laterne",
#         "dateObserved": "2024-05-28T02:39:06Z",
#         "temperature": 11.573586,
#         "relativeHumidity": 92.16319
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.30673,
#           47.089134
#         ]
#       },
#       "properties": {
#         "stationId": "4DE350FEFF6E959E",
#         "name": "Industriering Nord",
#         "dateObserved": "2024-05-28T02:26:13Z",
#         "temperature": 11.103609,
#         "relativeHumidity": 85.14595
#       }
#     }
#   ]
# }

# %% [markdown]
# Loading the data as GeoPandas dataframe improves the readability of the data in a single step:

# %%
stations = gpd.read_file(response.text)

# Display stations DataFrame
stations
# Out:
#             stationId                                  name  \
# 0    1E0551FEFF6E959E                          Wankdorf ESP
# 1    0940CBFEFFE70FFE  Kreuzung Brunnmatt-Schwarztorstrasse
# 2    270551FEFF6E959E                  Galgenfeld Industrie
# 3    F5C450FEFF6E959E                           Rosengarten
# 4    1840CBFEFFE70FFE                            Bärenplatz
# ..                ...                                   ...
# 119  3A0551FEFF6E959E                            Eigerplatz
# 120  ECC450FEFF6E959E                        Wankdorf ESP 2
# 121  4B40CBFEFFE70FFE                              Köniztal
# 122  7FEA50FEFF6E959E     Wohlen Hinterkappelenring Laterne
# 123  4DE350FEFF6E959E                    Industriering Nord
#
#                  dateObserved  temperature  relativeHumidity  \
# 0   2024-05-28 02:55:36+00:00    11.258488         87.814380
# 1   2024-05-28 02:55:32+00:00    11.285192         90.938660
# 2   2024-05-28 02:55:29+00:00    10.809873         95.518270
# 3   2024-05-28 02:55:08+00:00    10.190356         95.966510
# 4   2024-05-28 02:55:02+00:00    11.458762         86.719536
# ..                        ...          ...               ...
# 119 2024-05-28 02:45:48+00:00    11.039521         90.393150
# 120 2024-05-28 02:45:44+00:00    11.287862         89.714120
# 121 2024-05-28 02:41:20+00:00     9.127565         99.291070
# 122 2024-05-28 02:39:06+00:00    11.573586         92.163190
# 123 2024-05-28 02:26:13+00:00    11.103609         85.145950
#
#                      geometry
# 0    POINT (7.46244 46.96798)
# 1    POINT (7.42713 46.94479)
# 2    POINT (7.47194 46.95553)
# 3    POINT (7.46020 46.95188)
# 4    POINT (7.44361 46.94826)
# ..                        ...
# 119  POINT (7.43141 46.94067)
# 120  POINT (7.46247 46.96800)
# 121  POINT (7.44248 46.90961)
# 122  POINT (7.37676 46.96736)
# 123  POINT (7.30673 47.08913)
#
# [124 rows x 6 columns]

# %% [markdown]
# ### Step 3: Visualisation on a map
#
# To start with, here is the code to display a map. It is automatically centered according to the average longitude and latitude of the weather stations.

# %%
# Create a base map
map1 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=10)

# Display map
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8963985e0e039d80969850ab41986cda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8963985e0e039d80969850ab41986cda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8963985e0e039d80969850ab41986cda = L.map(
#                 &quot;map_8963985e0e039d80969850ab41986cda&quot;,
#                 {
#                     center: [46.95511521774193, 7.442288527419355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c917c42279a0f6518bef5412b605d6c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8963985e0e039d80969850ab41986cda);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Second, we display the location of the weather stations, but without weather data measurements:

# %%
# Create a base map
map2 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=10)

# Iterate through each station in the GeoPandas DataFrame
for idx, station in stations.iterrows():
    # Create a circle marker for each station and add it to the map
    folium.CircleMarker(
        # Location of the marker in lat and lon
        location=(station.geometry.y, station.geometry.x),
        # Styling the marker
        radius=5,
        color="black",  # Border color
        weight=0.5,  # Border width
        fill=True,
        fill_color="black",
        fill_opacity=1, # 1 means 100% opaque
        # Add a tooltip with station name
        tooltip=f"{station['name']}",
    # Add the marker to the map
    ).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52b4853d037e1923e63e4f005beffa25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52b4853d037e1923e63e4f005beffa25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52b4853d037e1923e63e4f005beffa25 = L.map(
#                 &quot;map_52b4853d037e1923e63e4f005beffa25&quot;,
#                 {
#                     center: [46.95511521774193, 7.442288527419355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_056b2e73494b43eb58424ba2146ae211 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52b4853d037e1923e63e4f005beffa25);
#
#
#             var circle_marker_cdaddcd6dd2143e140bf419506cf023e = L.circleMarker(
#                 [46.96798, 7.46244],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_52b4853d037e1923e63e4f005beffa25);
#
#
#             circle_marker_cdaddcd6dd2143e140bf419506cf023e.bindTooltip(
#                 `&lt;div&gt;
#                      Wankdorf ESP
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c2db169a836729bd45632b24a5b440ad = L.circleMarker(
#                 [46.94479, 7.42713],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_52b4853d037e1923e63e4f005beffa25);
#
#
#             circle_marker_c2db169a836729bd45632b24a5b440ad.bindTooltip(
#                 `&lt;div&gt;
#                      Kreuzung Brunnmatt-Schwarztorstrasse
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f4ead35cb6def99864f9173b3cde354f = L.circleMarker(
#                 [46.95553, 7.47194],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_52b4853d037e1923e63e4f005beffa25);
#
#
#             circle_marker_f4ead35cb6def99864f9173b3cde354f.bindTooltip(
#                 `&lt;div&gt;
#                      Galgenfeld Industrie
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_711a228e77287fddf0114cb63d2ecef6 = L.circleMarker(
#                 [46.95188, 7.4602],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 0.5}
#             ).addTo(map_52b4853d037e1923e63e4f005beffa25);
#
#
#             circle_marker_711a228e77287fddf0114cb63d2ecef6.bindTooltip(
#                 `&lt;div&gt;
#                      Rosengarten
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_d2afce381c5694efe1ea7b4833cb6b85 = L.circleMarker(
#                 [46.94826, 7.44361],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot

# %% [markdown]
# And finally, we can give the weather stations a colour depending on the current temperature and also add tooltips:

# %%
# Create a base map
map3 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=13)#, tiles="CartoDB positron")

# Most popular colormaps are sequential, meaning that they have a start and end color
# Define a function to reverse a colormap
def reversed_colormap(existing):
    return branca.colormap.LinearColormap(
        colors=list(reversed(existing.colors)),
        vmin=existing.vmin, vmax=existing.vmax
    )

def formatToolTip(stationName, temperature, humidity):
    return f"{stationName}: {temperature:.2f}°C, {humidity:.2f}%"

def formatToolTip2(stationName, temperature, humidity):
    return f"<h4>{stationName}</h4>Temperature: {temperature:.2f}°C<br/>Humidity: {humidity:.2f}%"


# Create a colormap for a temperature range of 10-37°C
# Choose an appropriate colormap (Spectral_11) and reverse it so that it goes from blue (cold) to red (hot)
colormap = reversed_colormap(branca.colormap.linear.Spectral_11)
# Scale the colormap to the temperature range and discretize it into 9 steps for better visibility
colormap = colormap.scale(0, 20).to_step(9)
# Add a caption to the colormap
colormap.caption = "Temperature (°C)"
# Add colormap to the map
colormap.add_to(map3)

# Iterate through each station in the GeoPandas DataFrame
for idx, station in stations.iterrows():
    # Create a circle marker for each station and add it to the map
    folium.CircleMarker(
        # Location of the marker in lon and lat
        location=(station.geometry.y, station.geometry.x),
        # Styling the marker
        radius=5,
        color="black",  # Border color
        weight=0.5,  # Border width
        fill=True,
        # Set the fill color to the colormap value corresponding to the station temperature
        fill_color=colormap(station['temperature']),
        fill_opacity=1, # 1 means 100% opaque
        # Add a tooltip with station name and temperature
        tooltip=formatToolTip2(station['name'], station['temperature'], station['relativeHumidity'])
    # Add the marker to the map
    ).add_to(map3)

# Display map
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48982d1f14c5200012d364a1c78234d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48982d1f14c5200012d364a1c78234d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48982d1f14c5200012d364a1c78234d0 = L.map(
#                 &quot;map_48982d1f14c5200012d364a1c78234d0&quot;,
#                 {
#                     center: [46.95511521774193, 7.442288527419355],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dd129402c7cf5049176f3afa03a92b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48982d1f14c5200012d364a1c78234d0);
#
#
#     var color_map_9906dc61eea353e6f96f722090e88481 = {};
#
#
#     color_map_9906dc61eea353e6f96f722090e88481.color = d3.scale.threshold()
#               .domain([0.0, 0.04008016032064128, 0.08016032064128256, 0.12024048096192384, 0.16032064128256512, 0.20040080160320642, 0.24048096192384769, 0.280561122244489, 0.32064128256513025, 0.36072144288577157, 0.40080160320641284, 0.4408817635270541, 0.48096192384769537, 0.5210420841683366, 0.561122244488978, 0.6012024048096193, 0.6412825651302605, 0.6813627254509018, 0.7214428857715431, 0.7615230460921844, 0.8016032064128257, 0.8416833667334669, 0.8817635270541082, 0.9218436873747495, 0.9619238476953907, 1.002004008016032, 1.0420841683366733, 1.0821643286573146, 1.122244488977956, 1.1623246492985972, 1.2024048096192386, 1.2424849699398797, 1.282565130260521, 1.3226452905811623, 1.3627254509018036, 1.402805611222445, 1.4428857715430863, 1.4829659318637274, 1.5230460921843687, 1.56312625250501, 1.6032064128256514, 1.6432865731462927, 1.6833667334669338, 1.723446893787575, 1.7635270541082164, 1.8036072144288577, 1.843687374749499, 1.8837675350701404, 1.9238476953907815, 1.9639278557114228, 2.004008016032064, 2.0440881763527052, 2.0841683366733466, 2.124248496993988, 2.164328657314629, 2.2044088176352705, 2.244488977955912, 2.284569138276553, 2.3246492985971945, 2.364729458917836, 2.404809619238477, 2.444889779559118, 2.4849699398797593, 2.5250501002004007, 2.565130260521042, 2.6052104208416833, 2.6452905811623246, 2.685370741482966, 2.7254509018036073, 2.7655310621242486, 2.80561122244489, 2.8456913827655312, 2.8857715430861726, 2.9258517034068134, 2.9659318637274548, 3.006012024048096, 3.0460921843687374, 3.0861723446893787, 3.12625250501002, 3.1663326653306614, 3.2064128256513027, 3.246492985971944, 3.2865731462925853, 3.3266533066132267, 3.3667334669338675, 3.406813627254509, 3.44689378757515, 3.4869739478957915, 3.527054108216433, 3.567134268537074, 3.6072144288577155, 3.647294589178357, 3.687374749498998, 3.7274549098196395, 3.7675350701402808, 3.8076152304609217, 3.847695390781563, 3.8877755511022043, 3.9278557114228456, 3.967935871743487, 4.008016032064128, 4.04809619238477, 4.0881763527054105, 4.128256513026052, 4.168336673346693, 4.208416833667335, 4.248496993987976, 4.2885771543086175, 4.328657314629258, 4.3687374749499, 4.408817635270541, 4.448897795591182, 4.488977955911824, 4.529058116232465, 4.569138276553106, 4.609218436873747, 4.649298597194389, 4.68937875751503, 4.729458917835672, 4.7695390781563125, 4.809619238476954, 4.849699398797595, 4.889779559118236, 4.929859719438878, 4.969939879759519, 5.01002004008016, 5.050100200400801, 5.090180360721443, 5.130260521042084, 5.170340681362726, 5.210420841683367, 5.250501002004008, 5.290581162324649, 5.330661322645291, 5.370741482965932, 5.410821643286573, 5.4509018036072145, 5.490981963927855, 5.531062124248497, 5.571142284569138, 5.61122244488978, 5.651302605210421, 5.6913827655310625, 5.731462925851703, 5.771543086172345, 5.811623246492986, 5.851703406813627, 5.891783567134269, 5.9318637274549095, 5.971943887775551, 6.012024048096192, 6.052104208416834, 6.092184368737475, 6.132264529058117, 6.1723446893787575, 6.212424849699399, 6.25250501002004, 6.292585170340681, 6.332665330661323, 6.372745490981964, 6.412825651302605, 6.452905811623246, 6.492985971943888, 6.533066132264529, 6.573146292585171, 6.613226452905812, 6.653306613226453, 6.693386773547094, 6.733466933867735, 6.773547094188377, 6.813627254509018, 6.8537074148296595, 6.8937875751503, 6.933867735470942, 6.973947895791583, 7.014028056112225, 7.054108216432866, 7.094188376753507, 7.134268537074148, 7.174348697394789, 7.214428857715431, 7.254509018036072, 7.294589178356714, 7.3346693386773545, 7.374749498997996, 7.414829659318637, 7.454909819639279, 7.49498997995992, 7.5350701402805615, 7.575150300601202, 7.615230460921843, 7.655310621242485, 7.695390781563126, 7.735470941883768, 7.775551102204409, 7.81563126252505, 7.8557114228456

# %% [markdown]
# ## Part 2 - Display Measurement Data over Time

# %% [markdown]
# ### Step 1: Query data for a specific weather station
#
# e.g., at the Government Plaza ("Bundesplatz" in German):

# %%
# Based on a station name, get the respective stationId from the DataFrame
stationId = stations[stations["name"] == "Bundesplatz"].stationId.values[0]
# Define the URL including the stationId argument
url = f"https://smart-urban-heat-map.ch/api/1.0/timeseries?stationId={stationId}"

# Define the headers to request CSV data as a python dictionary
headers = {
    "Accept": "text/csv"
}

# Make the GET request with the headers
response = requests.get(url, headers=headers)

# Get the timeseries into a data frame
timeseries = pd.read_csv(io.StringIO(response.text), delimiter=";")

timeseries
# Out:
#           dateObserved  temperature  relativeHumidity
# 0    2024-05-26T03:02Z    10.486763         85.023880
# 1    2024-05-26T03:12Z    10.558862         83.740210
# 2    2024-05-26T03:22Z    10.273136         84.035860
# 3    2024-05-26T03:32Z    10.195697         84.398260
# 4    2024-05-26T03:42Z     9.901960         85.191730
# ..                 ...          ...               ...
# 281  2024-05-28T02:12Z    11.359961         87.902115
# 282  2024-05-28T02:22Z    11.370642         88.089035
# 283  2024-05-28T02:32Z    11.327916         87.883040
# 284  2024-05-28T02:42Z    11.258488         86.978940
# 285  2024-05-28T02:52Z    11.191730         87.980316
#
# [286 rows x 3 columns]

# %% [markdown]
# ### Step 2: Show data in a graph
#
# By default, the data from the last 48 hours is returned.

# %%
# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
ax = timeseries.plot(x='dateObserved', y='temperature', figsize=(10,6), marker=None, linestyle='-')
# The ax object is a matplotlib axis object which we can use to further customize the plot

# Add a title
ax.set_title('Bundesplatz')

# Add labels for the x and y axes
ax.set_xlabel('Time')
ax.set_ylabel('Temperature (°C)')

# Shift every second x-label for better readability
for i, label in enumerate(ax.get_xticklabels()):
    if i % 2 == 0:  # Check if it's an odd tick
        label.set_y(-0.04)

# %% [markdown]
# ### Step 3: Display data from multiple stations in a specific time period
# First, we set the time period:

# %%
startTime = "2024-04-28T00:00:00Z" # 28.09.23 00:00 ; Z means UTC time
endTime = "2024-04-30T23:00:00Z" # 31.09.23 23:00

# %% [markdown]
# Now we can query and display the data:

# %%
import matplotlib.pyplot as plt

# Define function to read the data for a specific station and a specific time range.
# Returns the data as a Pandas dataframe
def getData(stationName, startTime, endTime):
    #Define the headers to request CSV data as a python dictionary
    headers = {
        "Accept": "text/csv"
    }

    # Read the data
    stationId = stations[stations["name"] == stationName].stationId.values[0]
    # Define the URL including the stationId argument
    url = f"https://smart-urban-heat-map.ch/api/1.0/timeseries?stationId={stationId}&timeFrom={startTime}&timeTo={endTime}"

    # Make the GET request with the headers
    response = requests.get(url, headers=headers)
    return pd.read_csv(io.StringIO(response.text), delimiter=";")

# Read the data for the 3 stations:
stationName1 = "Bundesplatz"
stationName2 = "Marktplatz Lyss"
stationName3 = "Ittigen Papiermühle Kreisel"
timeseries1 = getData(stationName1, startTime, endTime)
timeseries2 = getData(stationName2, startTime, endTime)
timeseries3 = getData(stationName3, startTime, endTime)

# Now plot the data
plt.figure(figsize=(10, 6))


# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
timeseries1.plot(x='dateObserved', y='temperature', label=stationName1, marker=None, color='blue', linestyle='-', ax=plt.gca())
timeseries2.plot(x='dateObserved', y='temperature', label=stationName2, marker=None, color='green', linestyle='-', ax=plt.gca())
timeseries3.plot(x='dateObserved', y='temperature', label=stationName3, marker=None, color='red', linestyle='-', ax=plt.gca())

plt.title('Temperature Curve')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
# Out:
# Text(0, 0.5, 'Temperature (°C)')

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6fcf9dfbd479> in <cell line: 1>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
timeseries1.plot(x='dateObserved', y='relativeHumidity', label=stationName1, marker=None, color='blue', linestyle='-', ax=plt.gca())
timeseries2.plot(x='dateObserved', y='relativeHumidity', label=stationName2, marker=None, color='green', linestyle='-', ax=plt.gca())
timeseries3.plot(x='dateObserved', y='relativeHumidity', label=stationName3, marker=None, color='red', linestyle='-', ax=plt.gca())
# Out:
# <Axes: xlabel='dateObserved'>
