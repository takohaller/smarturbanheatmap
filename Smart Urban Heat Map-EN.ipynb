# %% [markdown]
# # Fincon Rowing Session on Smart City and IoT
# Dieses Beispiel zeigt, wie mit einfachem Code in Python Daten von Wetterstationen in der Region Bern ausgelesen und visualisiert werden können.
#
# API Dokumentation: https://meteotest.github.io/urban-heat-API-docs/de/
#
# Entwickelt im Rahmen des Projektes __[Smart Urban Heat Map Bern](https://smart-urban-heat-map.ch/)__.

# %% [markdown]
# ## Teil 1 - Laden und Darstellen von aktuellen Daten

# %% [markdown]
# ### Schritt 1: Importieren der benötigten Python Libraries

# %%
import io # for working with streams (like strings)
import requests # for making standard HTTP requests
import pandas as pd # for storing and manipulating data
import geopandas as gpd # for storing and manipulating geographic data
import folium # for creating maps
import branca # for using colorscales in Folium
import json # for data handling

# %% [markdown]
# ### Schritt 2: Liste aller Messstationen abfragen

# %%
# Define the URL
url = "https://smart-urban-heat-map.ch/api/1.0/stations"

# Make the GET request
response = requests.get(url)

# Display the result
print(response.text)
# Out:
# {"type": "FeatureCollection", "features": [{"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.4133654, 46.938255]}, "properties": {"stationId": "D7DD50FEFF6E959E", "name": "Liebefeld Turnierstrasse Laterne", "dateObserved": "2024-05-13T00:21:06Z", "temperature": 12.177081, "relativeHumidity": 86.891205}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.42946, 46.94672]}, "properties": {"stationId": "9FD350FEFF6E959E", "name": "Emch+Berger (Schl\u00f6sslistrasse) Pfosten Eingang", "dateObserved": "2024-05-13T00:21:03Z", "temperature": 15.063706, "relativeHumidity": 69.024796}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.45326, 46.93122]}, "properties": {"stationId": "3740CBFEFFE70FFE", "name": "Wabern Viktoriastrasse", "dateObserved": "2024-05-13T00:20:57Z", "temperature": 14.20119, "relativeHumidity": 82.63584}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.48807, 46.95813]}, "properties": {"stationId": "0F40CBFEFFE70FFE", "name": "Ostermuniugen Moosweg", "dateObserved": "2024-05-13T00:20:54Z", "temperature": 14.839398, "relativeHumidity": 77.92844}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.4285746, 46.95617]}, "properties": {"stationId": "593FCBFEFFE70FFE", "name": "Bern Hintere L\u00e4nggasse", "dateObserved": "2024-05-13T00:20:51Z", "temperature": 15.162509, "relativeHumidity": 71.33845}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.41688, 46.94211]}, "properties": {"stationId": "1140CBFEFFE70FFE", "name": "Schlossmatte Familieng\u00e4rten", "dateObserved": "2024-05-13T00:20:49Z", "temperature": 14.011597, "relativeHumidity": 88.36179}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.49879, 46.95566]}, "properties": {"stationId": "D40451FEFF6E959E", "name": "Ostermundigen Ahornstrasse 16", "dateObserved": "2024-05-13T00:20:47Z", "temperature": 13.755245, "relativeHumidity": 86.81491}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.712437, 46.713448]}, "properties": {"stationId": "4640CBFEFFE70FFE", "name": "Sigriswil", "dateObserved": "2024-05-13T00:20:28Z", "temperature": 13.255894, "relativeHumidity": 81.06035}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.45802, 46.95696]}, "properties": {"stationId": "4940CBFEFFE70FFE", "name": "Kasernenareal", "dateObserved": "2024-05-13T00:20:23Z", "temperature": 15.117113, "relativeHumidity": 76.982376}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.4695, 46.93558]}, "properties": {"stationId": "1E40CBFEFFE70FFE", "name": "Elfenau", "dateObserved": "2024-05-13T00:20:20Z", "temperature": 14.425498, "relativeHumidity": 80.30694}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.45935, 46.92921]}, "properties": {"stationId": "17D950FEFF6E959E", "name": "Wabern Weyergut", "dateObserved": "2024-05-13T00:20:15Z", "temperature": 14.20386, "relativeHumidity": 76.66956}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43462, 46.94187]}, "properties": {"stationId": "0640CBFEFFE70FFE", "name": "Monbijou-Park", "dateObserved": "2024-05-13T00:20:14Z", "temperature": 14.211871, "relativeHumidity": 81.67071}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.45978, 46.97857]}, "properties": {"stationId": "1EDE50FEFF6E959E", "name": "Ittigen Worblaufenstrasse  Laterne", "dateObserved": "2024-05-13T00:20:10Z", "temperature": 14.988937, "relativeHumidity": 73.89052}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.43688, 46.96271]}, "properties": {"stationId": "1240CBFEFFE70FFE", "name": "Viererfeld 2 (Schacht)", "dateObserved": "2024-05-13T00:20:07Z", "temperature": 14.799344, "relativeHumidity": 77.15976}}, {"type": "Feature", "geometry": {"type": "Point", "coordinates": [7.4540253, 46.958252]}, "properties": {"stationId": "1540CBFEFFE70FFE", "name": "Breitenrainplatz 127", "dateObserved": "2024-0 ...

# %% [markdown]
# Umformatierung für bessere Lesbarkeit:

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4133654,
#           46.938255
#         ]
#       },
#       "properties": {
#         "stationId": "D7DD50FEFF6E959E",
#         "name": "Liebefeld Turnierstrasse Laterne",
#         "dateObserved": "2024-05-13T00:21:06Z",
#         "temperature": 12.177081,
#         "relativeHumidity": 86.891205
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42946,
#           46.94672
#         ]
#       },
#       "properties": {
#         "stationId": "9FD350FEFF6E959E",
#         "name": "Emch+Berger (Schl\u00f6sslistrasse) Pfosten Eingang",
#         "dateObserved": "2024-05-13T00:21:03Z",
#         "temperature": 15.063706,
#         "relativeHumidity": 69.024796
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45326,
#           46.93122
#         ]
#       },
#       "properties": {
#         "stationId": "3740CBFEFFE70FFE",
#         "name": "Wabern Viktoriastrasse",
#         "dateObserved": "2024-05-13T00:20:57Z",
#         "temperature": 14.20119,
#         "relativeHumidity": 82.63584
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48807,
#           46.95813
#         ]
#       },
#       "properties": {
#         "stationId": "0F40CBFEFFE70FFE",
#         "name": "Ostermuniugen Moosweg",
#         "dateObserved": "2024-05-13T00:20:54Z",
#         "temperature": 14.839398,
#         "relativeHumidity": 77.92844
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4285746,
#           46.95617
#         ]
#       },
#       "properties": {
#         "stationId": "593FCBFEFFE70FFE",
#         "name": "Bern Hintere L\u00e4nggasse",
#         "dateObserved": "2024-05-13T00:20:51Z",
#         "temperature": 15.162509,
#         "relativeHumidity": 71.33845
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41688,
#           46.94211
#         ]
#       },
#       "properties": {
#         "stationId": "1140CBFEFFE70FFE",
#         "name": "Schlossmatte Familieng\u00e4rten",
#         "dateObserved": "2024-05-13T00:20:49Z",
#         "temperature": 14.011597,
#         "relativeHumidity": 88.36179
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49879,
#           46.95566
#         ]
#       },
#       "properties": {
#         "stationId": "D40451FEFF6E959E",
#         "name": "Ostermundigen Ahornstrasse 16",
#         "dateObserved": "2024-05-13T00:20:47Z",
#         "temperature": 13.755245,
#         "relativeHumidity": 86.81491
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.712437,
#           46.713448
#         ]
#       },
#       "properties": {
#         "stationId": "4640CBFEFFE70FFE",
#         "name": "Sigriswil",
#         "dateObserved": "2024-05-13T00:20:28Z",
#         "temperature": 13.255894,
#         "relativeHumidity": 81.06035
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45802,
#           46.95696
#         ]
#       },
#       "properties": {
#         "stationId": "4940CBFEFFE70FFE",
#         "name": "Kasernenareal",
#         "dateObserved": "2024-05-13T00:20:23Z",
#         "temperature": 15.117113,
#         "relativeHumidity": 76.982376
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4695,
#           46.93558
#         ]
#       },
#       "properties": {
#         "stationId": "1E40CBFEFFE70FFE",
#         "name": "Elfenau",
#         "dateObserved": "2024-05-13T00:20:20Z",
#         "temperature": 14.425498,
#         "relativeHumidity": 80.30694
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45935,
#           46.92921
#         ]
#       },
#       "properties": {
#         "stationId": "17D950FEFF6E959E",
#         "name": "Wabern Weyergut",
#         "dateObserved": "2024-05-13T00:20:15Z",
#         "temperature": 14.20386,
#         "relativeHumidity": 76.66956
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43462,
#           46.94187
#         ]
#       },
#       "properties": {
#         "stationId": "0640CBFEFFE70FFE",
#         "name": "Monbijou-Park",
#         "dateObserved": "2024-05-13T00:20:14Z",
#         "temperature": 14.211871,
#         "relativeHumidity": 81.67071
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45978,
#           46.97857
#         ]
#       },
#       "properties": {
#         "stationId": "1EDE50FEFF6E959E",
#         "name": "Ittigen Worblaufenstrasse  Laterne",
#         "dateObserved": "2024-05-13T00:20:10Z",
#         "temperature": 14.988937,
#         "relativeHumidity": 73.89052
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43688,
#           46.96271
#         ]
#       },
#       "properties": {
#         "stationId": "1240CBFEFFE70FFE",
#         "name": "Viererfeld 2 (Schacht)",
#         "dateObserved": "2024-05-13T00:20:07Z",
#         "temperature": 14.799344,
#         "relativeHumidity": 77.15976
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4540253,
#           46.958252
#         ]
#       },
#       "properties": {
#         "stationId": "1540CBFEFFE70FFE",
#         "name": "Breitenrainplatz 127",
#         "dateObserved": "2024-05-13T00:19:58Z",
#         "temperature": 15.202563,
#         "relativeHumidity": 75.62432
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.525039,
#           46.9585
#         ]
#       },
#       "properties": {
#         "stationId": "2BD650FEFF6E959E",
#         "name": "Stettlen Bernstrasse Laterne",
#         "dateObserved": "2024-05-13T00:19:57Z",
#         "temperature": 14.067674,
#         "relativeHumidity": 78.92409
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.451387,
#           46.99095
#         ]
#       },
#       "properties": {
#         "stationId": "40DE50FEFF6E959E",
#         "name": "Zollikofen Reichenbach Laterne",
#         "dateObserved": "2024-05-13T00:19:31Z",
#         "temperature": 13.7579155,
#         "relativeHumidity": 81.86145
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44007,
#           46.93354
#         ]
#       },
#       "properties": {
#         "stationId": "11D450FEFF6E959E",
#         "name": "Morillongut (Sch\u00f6negg) Mast",
#         "dateObserved": "2024-05-13T00:19:26Z",
#         "temperature": 13.971542,
#         "relativeHumidity": 80.51293
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44122,
#           46.97417
#         ]
#       },
#       "properties": {
#         "stationId": "D83FCBFEFFE70FFE",
#         "name": "Felsenhaldeweg",
#         "dateObserved": "2024-05-13T00:19:26Z",
#         "temperature": 13.271915,
#         "relativeHumidity": 90.14137
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40995,
#           46.92041
#         ]
#       },
#       "properties": {
#         "stationId": "0A0551FEFF6E959E",
#         "name": "K\u00f6niz Aussenquartier",
#         "dateObserved": "2024-05-13T00:19:15Z",
#         "temperature": 12.607004,
#         "relativeHumidity": 91.94957
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42571,
#           46.94719
#         ]
#       },
#       "properties": {
#         "stationId": "DA0451FEFF6E959E",
#         "name": "Inselspital",
#         "dateObserved": "2024-05-13T00:19:05Z",
#         "temperature": 15.9823,
#         "relativeHumidity": 69.79729
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.377091,
#           46.92567
#         ]
#       },
#       "properties": {
#         "stationId": "76DA50FEFF6E959E",
#         "name": "Niederwangen Zentrum Laterne",
#         "dateObserved": "2024-05-13T00:19:01Z",
#         "temperature": 13.22385,
#         "relativeHumidity": 82.202866
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37676,
#           46.96736
#         ]
#       },
#       "properties": {
#         "stationId": "7FEA50FEFF6E959E",
#         "name": "Wohlen Hinterkappelenring Laterne",
#         "dateObserved": "2024-05-13T00:18:58Z",
#         "temperature": 13.605707,
#         "relativeHumidity": 81.930115
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41453,
#           46.92282
#         ]
#       },
#       "properties": {
#         "stationId": "FED550FEFF6E959E",
#         "name": "K\u00f6niz Bl\u00e4uacker Park Aldi/Swisscom",
#         "dateObserved": "2024-05-13T00:18:58Z",
#         "temperature": 13.231861,
#         "relativeHumidity": 82.85901
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44773,
#           46.95518
#         ]
#       },
#       "properties": {
#         "stationId": "130551FEFF6E959E",
#         "name": "Viktoriarain",
#         "dateObserved": "2024-05-13T00:18:57Z",
#         "temperature": 15.429542,
#         "relativeHumidity": 73.59678
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44571,
#           46.94445
#         ]
#       },
#       "properties": {
#         "stationId": "E40451FEFF6E959E",
#         "name": "Dalmazibr\u00fccke",
#         "dateObserved": "2024-05-13T00:18:57Z",
#         "temperature": 13.95819,
#         "relativeHumidity": 84.720604
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37478,
#           46.94555
#         ]
#       },
#       "properties": {
#         "stationId": "E00451FEFF6E959E",
#         "name": "Westside Center",
#         "dateObserved": "2024-05-13T00:18:41Z",
#         "temperature": 14.03563,
#         "relativeHumidity": 86.79202
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.30673,
#           47.089134
#         ]
#       },
#       "properties": {
#         "stationId": "4DE350FEFF6E959E",
#         "name": "Industriering Nord",
#         "dateObserved": "2024-05-13T00:18:38Z",
#         "temperature": 15.269321,
#         "relativeHumidity": 70.588844
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49371,
#           46.95806
#         ]
#       },
#       "properties": {
#         "stationId": "280551FEFF6E959E",
#         "name": "Ostermundigen Wegm\u00fchleng\u00e4ssli",
#         "dateObserved": "2024-05-13T00:18:37Z",
#         "temperature": 14.724575,
#         "relativeHumidity": 79.56687
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46257,
#           46.96311
#         ]
#       },
#       "properties": {
#         "stationId": "3340CBFEFFE70FFE",
#         "name": "Stadtlabor",
#         "dateObserved": "2024-05-13T00:18:35Z",
#         "temperature": 15.320058,
#         "relativeHumidity": 74.825134
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44082,
#           46.95151
#         ]
#       },
#       "properties": {
#         "stationId": "0F0551FEFF6E959E",
#         "name": "Bollwerk Strasseninsel",
#         "dateObserved": "2024-05-13T00:18:27Z",
#         "temperature": 15.819409,
#         "relativeHumidity": 72.74418
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43786,
#           46.94658
#         ]
#       },
#       "properties": {
#         "stationId": "ED3FCBFEFFE70FFE",
#         "name": "Hirschengraben",
#         "dateObserved": "2024-05-13T00:18:26Z",
#         "temperature": 14.988937,
#         "relativeHumidity": 75.692986
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.481412,
#           46.94348
#         ]
#       },
#       "properties": {
#         "stationId": "5AE350FEFF6E959E",
#         "name": "Bern Merzenacker",
#         "dateObserved": "2024-05-13T00:18:23Z",
#         "temperature": 14.129091,
#         "relativeHumidity": 72.85672
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40134,
#           46.949
#         ]
#       },
#       "properties": {
#         "stationId": "C33FCBFEFFE70FFE",
#         "name": "Weyermannshaus Industrie 2",
#         "dateObserved": "2024-05-13T00:18:17Z",
#         "temperature": 15.050355,
#         "relativeHumidity": 78.45678
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.308954,
#           47.0709
#         ]
#       },
#       "properties": {
#         "stationId": "24E350FEFF6E959E",
#         "name": "M\u00fchleplatz Lyss",
#         "dateObserved": "2024-05-13T00:18:17Z",
#         "temperature": 14.836728,
#         "relativeHumidity": 73.35645
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.301668,
#           47.077145
#         ]
#       },
#       "properties": {
#         "stationId": "E3E250FEFF6E959E",
#         "name": "Reitplatz Gr\u00fcnau",
#         "dateObserved": "2024-05-13T00:18:13Z",
#         "temperature": 14.190509,
#         "relativeHumidity": 76.71534
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43739,
#           46.92607
#         ]
#       },
#       "properties": {
#         "stationId": "200551FEFF6E959E",
#         "name": "Spiegel",
#         "dateObserved": "2024-05-13T00:18:07Z",
#         "temperature": 13.637751,
#         "relativeHumidity": 81.83093
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.49792,
#           46.9581
#         ]
#       },
#       "properties": {
#         "stationId": "020551FEFF6E959E",
#         "name": "Ostermundigen Oberfeld",
#         "dateObserved": "2024-05-13T00:18:03Z",
#         "temperature": 14.649805,
#         "relativeHumidity": 78.57122
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44894,
#           46.94391
#         ]
#       },
#       "properties": {
#         "stationId": "EB3FCBFEFFE70FFE",
#         "name": "Helvetiaplatz neu",
#         "dateObserved": "2024-05-13T00:17:59Z",
#         "temperature": 15.17052,
#         "relativeHumidity": 77.15213
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42015,
#           46.9503
#         ]
#       },
#       "properties": {
#         "stationId": "1440CBFEFFE70FFE",
#         "name": "Bremgartenfriedhof",
#         "dateObserved": "2024-05-13T00:17:51Z",
#         "temperature": 14.235905,
#         "relativeHumidity": 83.414055
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46987,
#           46.95063
#         ]
#       },
#       "properties": {
#         "stationId": "410551FEFF6E959E",
#         "name": "Galgenfeld Neubausiedlung",
#         "dateObserved": "2024-05-13T00:17:48Z",
#         "temperature": 14.425498,
#         "relativeHumidity": 79.5993
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40896,
#           46.92981
#         ]
#       },
#       "properties": {
#         "stationId": "62E350FEFF6E959E",
#         "name": "K\u00f6niz Gartenstadt Laterne",
#         "dateObserved": "2024-05-13T00:17:43Z",
#         "temperature": 12.604334,
#         "relativeHumidity": 86.1149
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.445022,
#           46.95565
#         ]
#       },
#       "properties": {
#         "stationId": "A9E450FEFF6E959E",
#         "name": "Bern Lorrainepark",
#         "dateObserved": "2024-05-13T00:17:43Z",
#         "temperature": 15.157168,
#         "relativeHumidity": 66.966736
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50944,
#           46.9377
#         ]
#       },
#       "properties": {
#         "stationId": "B3C450FEFF6E959E",
#         "name": "G\u00fcmligen Dentenberg Laterne",
#         "dateObserved": "2024-05-13T00:17:33Z",
#         "temperature": 13.963531,
#         "relativeHumidity": 77.722435
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4986053,
#           46.92633
#         ]
#       },
#       "properties": {
#         "stationId": "B7D350FEFF6E959E",
#         "name": "Muri Steinh\u00fcbeliweg",
#         "dateObserved": "2024-05-13T00:17:28Z",
#         "temperature": 14.412147,
#         "relativeHumidity": 74.04501
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48628,
#           46.93048
#         ]
#       },
#       "properties": {
#         "stationId": "693FCBFEFFE70FFE",
#         "name": "Muri Zentrum (Tavelweg) Laterne",
#         "dateObserved": "2024-05-13T00:17:12Z",
#         "temperature": 14.68719,
#         "relativeHumidity": 73.40414
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42031,
#           46.92781
#         ]
#       },
#       "properties": {
#         "stationId": "2C40CBFEFFE70FFE",
#         "name": "K\u00f6niz Neubausiedlung",
#         "dateObserved": "2024-05-13T00:17:09Z",
#         "temperature": 13.525597,
#         "relativeHumidity": 87.73235
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40642,
#           46.94542
#         ]
#       },
#       "properties": {
#         "stationId": "010551FEFF6E959E",
#         "name": "Ausserholligen 2, ewb",
#         "dateObserved": "2024-05-13T00:16:56Z",
#         "temperature": 14.777981,
#         "relativeHumidity": 81.82521
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4377694,
#           46.938946
#         ]
#       },
#       "properties": {
#         "stationId": "D4C050FEFF6E959E",
#         "name": "Bern Sulgenau",
#         "dateObserved": "2024-05-13T00:16:56Z",
#         "temperature": 14.321355,
#         "relativeHumidity": 78.08865
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.464513,
#           46.90957
#         ]
#       },
#       "properties": {
#         "stationId": "E8E450FEFF6E959E",
#         "name": "Kehrsatz Breit\u00e4gertenstrasse Laterne",
#         "dateObserved": "2024-05-13T00:16:46Z",
#         "temperature": 14.585717,
#         "relativeHumidity": 68.307625
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.455911,
#           46.92579
#         ]
#       },
#       "properties": {
#         "stationId": "E7E450FEFF6E959E",
#         "name": "Wabern Gartentower Laterne",
#         "dateObserved": "2024-05-13T00:16:39Z",
#         "temperature": 14.743267,
#         "relativeHumidity": 73.419395
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44165,
#           46.96523
#         ]
#       },
#       "properties": {
#         "stationId": "1040CBFEFFE70FFE",
#         "name": "Viererfeld 4 (Strasse Nord)",
#         "dateObserved": "2024-05-13T00:16:28Z",
#         "temperature": 14.740597,
#         "relativeHumidity": 77.657585
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.448146,
#           46.93012
#         ]
#       },
#       "properties": {
#         "stationId": "B8D350FEFF6E959E",
#         "name": "Wabern Zentrum Laterne",
#         "dateObserved": "2024-05-13T00:16:19Z",
#         "temperature": 14.721905,
#         "relativeHumidity": 73.15045
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46407,
#           46.99079
#         ]
#       },
#       "properties": {
#         "stationId": "3B40CBFEFFE70FFE",
#         "name": "Zollikofen 3m",
#         "dateObserved": "2024-05-13T00:16:09Z",
#         "temperature": 14.452201,
#         "relativeHumidity": 84.24376
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43639,
#           46.94734
#         ]
#       },
#       "properties": {
#         "stationId": "3940CBFEFFE70FFE",
#         "name": "Laupenstrasse",
#         "dateObserved": "2024-05-13T00:16:07Z",
#         "temperature": 15.787366,
#         "relativeHumidity": 71.376595
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.438822,
#           46.977913
#         ]
#       },
#       "properties": {
#         "stationId": "57D550FEFF6E959E",
#         "name": "Bremgarten Ecke Lindenstrasse / Ritterstrasse Laterne",
#         "dateObserved": "2024-05-13T00:16:07Z",
#         "temperature": 14.11841,
#         "relativeHumidity": 79.269325
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.392484,
#           46.951385
#         ]
#       },
#       "properties": {
#         "stationId": "12E350FEFF6E959E",
#         "name": "Bern Bethlehem Laterne",
#         "dateObserved": "2024-05-13T00:16:04Z",
#         "temperature": 14.852751,
#         "relativeHumidity": 74.84421
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.497151,
#           46.975468
#         ]
#       },
#       "properties": {
#         "stationId": "C9EA50FEFF6E959E",
#         "name": "Bolligen Sternenkreisel Laterne",
#         "dateObserved": "2024-05-13T00:15:57Z",
#         "temperature": 14.68986,
#         "relativeHumidity": 72.73655
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43843,
#           46.94728
#         ]
#       },
#       "properties": {
#         "stationId": "FE3FCBFEFFE70FFE",
#         "name": "Bubenbergplatz",
#         "dateObserved": "2024-05-13T00:15:56Z",
#         "temperature": 15.376135,
#         "relativeHumidity": 74.89761
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.470893,
#           46.90922
#         ]
#       },
#       "properties": {
#         "stationId": "11E350FEFF6E959E",
#         "name": "Kehrsatz Zentrum Laterne",
#         "dateObserved": "2024-05-13T00:15:53Z",
#         "temperature": 14.425498,
#         "relativeHumidity": 75.66247
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "100551FEFF6E959E",
#         "name": "Gurten Kulm",
#         "dateObserved": "2024-05-13T00:15:49Z",
#         "temperature": 13.824674,
#         "relativeHumidity": 68.94278
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43141,
#           46.94067
#         ]
#       },
#       "properties": {
#         "stationId": "3A0551FEFF6E959E",
#         "name": "Eigerplatz",
#         "dateObserved": "2024-05-13T00:15:43Z",
#         "temperature": 14.826047,
#         "relativeHumidity": 77.764404
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46244,
#           46.96798
#         ]
#       },
#       "properties": {
#         "stationId": "1E0551FEFF6E959E",
#         "name": "Wankdorf ESP",
#         "dateObserved": "2024-05-13T00:15:38Z",
#         "temperature": 15.373465,
#         "relativeHumidity": 72.49813
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47194,
#           46.95553
#         ]
#       },
#       "properties": {
#         "stationId": "270551FEFF6E959E",
#         "name": "Galgenfeld Industrie",
#         "dateObserved": "2024-05-13T00:15:21Z",
#         "temperature": 15.018311,
#         "relativeHumidity": 75.1284
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42713,
#           46.94479
#         ]
#       },
#       "properties": {
#         "stationId": "0940CBFEFFE70FFE",
#         "name": "Kreuzung Brunnmatt-Schwarztorstrasse",
#         "dateObserved": "2024-05-13T00:15:17Z",
#         "temperature": 15.301366,
#         "relativeHumidity": 75.44694
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.4602,
#           46.95188
#         ]
#       },
#       "properties": {
#         "stationId": "F5C450FEFF6E959E",
#         "name": "Rosengarten",
#         "dateObserved": "2024-05-13T00:14:57Z",
#         "temperature": 14.799344,
#         "relativeHumidity": 78.68757
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44361,
#           46.94826
#         ]
#       },
#       "properties": {
#         "stationId": "1840CBFEFFE70FFE",
#         "name": "B\u00e4renplatz",
#         "dateObserved": "2024-05-13T00:14:53Z",
#         "temperature": 15.312047,
#         "relativeHumidity": 74.49897
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50376,
#           46.96681
#         ]
#       },
#       "properties": {
#         "stationId": "140551FEFF6E959E",
#         "name": "Umland Bolligen",
#         "dateObserved": "2024-05-13T00:14:31Z",
#         "temperature": 12.956817,
#         "relativeHumidity": 90.196686
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.29574,
#           47.075085
#         ]
#       },
#       "properties": {
#         "stationId": "94D650FEFF6E959E",
#         "name": "Sportanlage Grien",
#         "dateObserved": "2024-05-13T00:14:29Z",
#         "temperature": 13.800641,
#         "relativeHumidity": 77.92081
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43714,
#           46.9517
#         ]
#       },
#       "properties": {
#         "stationId": "D53FCBFEFFE70FFE",
#         "name": "L\u00e4nggasse Falkenweg",
#         "dateObserved": "2024-05-13T00:14:26Z",
#         "temperature": 14.540322,
#         "relativeHumidity": 80.167694
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46407,
#           46.94714
#         ]
#       },
#       "properties": {
#         "stationId": "1C40CBFEFFE70FFE",
#         "name": "Obstberg, Wattenwylweg 32",
#         "dateObserved": "2024-05-13T00:14:26Z",
#         "temperature": 15.114443,
#         "relativeHumidity": 77.15213
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.39587,
#           46.94302
#         ]
#       },
#       "properties": {
#         "stationId": "0C0551FEFF6E959E",
#         "name": "B\u00fcmpliz St\u00f6ckacker",
#         "dateObserved": "2024-05-13T00:14:22Z",
#         "temperature": 14.420157,
#         "relativeHumidity": 80.79523
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44513,
#           46.95898
#         ]
#       },
#       "properties": {
#         "stationId": "EA3FCBFEFFE70FFE",
#         "name": "Lorraine, Steckweg 17",
#         "dateObserved": "2024-05-13T00:14:19Z",
#         "temperature": 15.605783,
#         "relativeHumidity": 73.04173
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42805,
#           46.93514
#         ]
#       },
#       "properties": {
#         "stationId": "F4C450FEFF6E959E",
#         "name": "Steinh\u00f6lzliwald",
#         "dateObserved": "2024-05-13T00:14:07Z",
#         "temperature": 13.78729,
#         "relativeHumidity": 84.789276
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.484087,
#           46.947945
#         ]
#       },
#       "properties": {
#         "stationId": "1A40CBFEFFE70FFE",
#         "name": "Ostermundigen Tiefenm\u00f6sli",
#         "dateObserved": "2024-05-13T00:13:58Z",
#         "temperature": 14.68719,
#         "relativeHumidity": 79.0824
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43094,
#           46.94195
#         ]
#       },
#       "properties": {
#         "stationId": "4540CBFEFFE70FFE",
#         "name": "P\u00e4rkli bei Eigerplatz",
#         "dateObserved": "2024-05-13T00:13:58Z",
#         "temperature": 14.788663,
#         "relativeHumidity": 78.31373
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42771,
#           46.92253
#         ]
#       },
#       "properties": {
#         "stationId": "7ED650FEFF6E959E",
#         "name": "K\u00f6niz Blinzernplateau Strom-/Telefonmast",
#         "dateObserved": "2024-05-13T00:13:57Z",
#         "temperature": 13.779278,
#         "relativeHumidity": 77.68429
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46146,
#           46.96017
#         ]
#       },
#       "properties": {
#         "stationId": "D43FCBFEFFE70FFE",
#         "name": "Tellstrasse",
#         "dateObserved": "2024-05-13T00:13:50Z",
#         "temperature": 15.269321,
#         "relativeHumidity": 74.30251
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42252,
#           46.95291
#         ]
#       },
#       "properties": {
#         "stationId": "1740CBFEFFE70FFE",
#         "name": "VonRoll",
#         "dateObserved": "2024-05-13T00:13:48Z",
#         "temperature": 15.178531,
#         "relativeHumidity": 85.666664
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48201,
#           46.96241
#         ]
#       },
#       "properties": {
#         "stationId": "6B0551FEFF6E959E",
#         "name": "Ostermundigen Milchstrasse",
#         "dateObserved": "2024-05-13T00:13:42Z",
#         "temperature": 14.892805,
#         "relativeHumidity": 78.78294
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45586,
#           46.94701
#         ]
#       },
#       "properties": {
#         "stationId": "1F40CBFEFFE70FFE",
#         "name": "Matte M\u00fchleplatz",
#         "dateObserved": "2024-05-13T00:13:41Z",
#         "temperature": 15.250629,
#         "relativeHumidity": 78.073395
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.30584,
#           47.073505
#         ]
#       },
#       "properties": {
#         "stationId": "59E350FEFF6E959E",
#         "name": "Marktplatz Lyss",
#         "dateObserved": "2024-05-13T00:13:31Z",
#         "temperature": 15.17052,
#         "relativeHumidity": 74.19951
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.299204,
#           47.071545
#         ]
#       },
#       "properties": {
#         "stationId": "7DE350FEFF6E959E",
#         "name": "Spielplatz Stiglimatt",
#         "dateObserved": "2024-05-13T00:13:16Z",
#         "temperature": 14.297322,
#         "relativeHumidity": 72.63546
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.51184,
#           46.89942
#         ]
#       },
#       "properties": {
#         "stationId": "4840CBFEFFE70FFE",
#         "name": "Umland Belp",
#         "dateObserved": "2024-05-13T00:13:14Z",
#         "temperature": 14.03563,
#         "relativeHumidity": 83.49607
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.386227,
#           46.928032
#         ]
#       },
#       "properties": {
#         "stationId": "10D850FEFF6E959E",
#         "name": "Niederwangen Papillon Laterne/Bush\u00e4uschen",
#         "dateObserved": "2024-05-13T00:13:09Z",
#         "temperature": 13.38674,
#         "relativeHumidity": 81.34455
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44009,
#           46.96286
#         ]
#       },
#       "properties": {
#         "stationId": "450551FEFF6E959E",
#         "name": "Viererfeld 3 (Strasse S\u00fcd)",
#         "dateObserved": "2024-05-13T00:13:09Z",
#         "temperature": 14.964904,
#         "relativeHumidity": 77.369576
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45192,
#           46.96173
#         ]
#       },
#       "properties": {
#         "stationId": "0240CBFEFFE70FFE",
#         "name": "Breitenrain, Waffenweg",
#         "dateObserved": "2024-05-13T00:13:02Z",
#         "temperature": 15.549706,
#         "relativeHumidity": 73.42512
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45045,
#           46.95597
#         ]
#       },
#       "properties": {
#         "stationId": "350551FEFF6E959E",
#         "name": "Optingenstrasse",
#         "dateObserved": "2024-05-13T00:13:00Z",
#         "temperature": 15.504311,
#         "relativeHumidity": 74.6363
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.42317,
#           46.93716
#         ]
#       },
#       "properties": {
#         "stationId": "2340CBFEFFE70FFE",
#         "name": "Eisenbahnquartier",
#         "dateObserved": "2024-05-13T00:12:50Z",
#         "temperature": 13.9822235,
#         "relativeHumidity": 85.680016
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.489671,
#           46.971962
#         ]
#       },
#       "properties": {
#         "stationId": "E2E250FEFF6E959E",
#         "name": "Ittigen Worblentalstrasse",
#         "dateObserved": "2024-05-13T00:12:48Z",
#         "temperature": 14.425498,
#         "relativeHumidity": 77.54505
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.477217,
#           46.974644
#         ]
#       },
#       "properties": {
#         "stationId": "95D650FEFF6E959E",
#         "name": "Ittigen Papierm\u00fchle Kreisel",
#         "dateObserved": "2024-05-13T00:12:45Z",
#         "temperature": 16.508354,
#         "relativeHumidity": 69.22125
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46247,
#           46.968
#         ]
#       },
#       "properties": {
#         "stationId": "ECC450FEFF6E959E",
#         "name": "Wankdorf ESP 2",
#         "dateObserved": "2024-05-13T00:12:44Z",
#         "temperature": 15.544366,
#         "relativeHumidity": 73.6292
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43971,
#           46.91833
#         ]
#       },
#       "properties": {
#         "stationId": "230551FEFF6E959E",
#         "name": "Gurten Kulm 2",
#         "dateObserved": "2024-05-13T00:12:41Z",
#         "temperature": 14.903486,
#         "relativeHumidity": 79.650795
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40188,
#           46.94755
#         ]
#       },
#       "properties": {
#         "stationId": "1A0551FEFF6E959E",
#         "name": "Ausserholligen Post",
#         "dateObserved": "2024-05-13T00:12:40Z",
#         "temperature": 14.783322,
#         "relativeHumidity": 76.63523
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.456929,
#           46.99266
#         ]
#       },
#       "properties": {
#         "stationId": "5FE350FEFF6E959E",
#         "name": "Zollikofen Zentrum Laterne",
#         "dateObserved": "2024-05-13T00:12:39Z",
#         "temperature": 14.828717,
#         "relativeHumidity": 74.3254
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44353,
#           46.94692
#         ]
#       },
#       "properties": {
#         "stationId": "0140CBFEFFE70FFE",
#         "name": "Bundesplatz",
#         "dateObserved": "2024-05-13T00:12:36Z",
#         "temperature": 15.733959,
#         "relativeHumidity": 73.30877
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48114,
#           46.95563
#         ]
#       },
#       "properties": {
#         "stationId": "D60451FEFF6E959E",
#         "name": "Ostermundigen B\u00e4reTower",
#         "dateObserved": "2024-05-13T00:12:35Z",
#         "temperature": 15.474937,
#         "relativeHumidity": 72.84909
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.50045,
#           46.93537
#         ]
#       },
#       "properties": {
#         "stationId": "FBDD50FEFF6E959E",
#         "name": "G\u00fcmligen (Worbstrasse) Laterne",
#         "dateObserved": "2024-05-13T00:12:23Z",
#         "temperature": 14.906157,
#         "relativeHumidity": 72.780426
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47186,
#           46.95339
#         ]
#       },
#       "properties": {
#         "stationId": "060551FEFF6E959E",
#         "name": "Schosshaldenfriedhof 2",
#         "dateObserved": "2024-05-13T00:12:22Z",
#         "temperature": 14.735256,
#         "relativeHumidity": 74.51232
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.310936,
#           47.075108
#         ]
#       },
#       "properties": {
#         "stationId": "3DD650FEFF6E959E",
#         "name": "Heilbachweg | Oberfeldweg",
#         "dateObserved": "2024-05-13T00:12:20Z",
#         "temperature": 14.182498,
#         "relativeHumidity": 75.11696
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.47992,
#           46.93919
#         ]
#       },
#       "properties": {
#         "stationId": "320551FEFF6E959E",
#         "name": "Murifeld",
#         "dateObserved": "2024-05-13T00:12:17Z",
#         "temperature": 14.959563,
#         "relativeHumidity": 77.199814
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.37708,
#           46.94787
#         ]
#       },
#       "properties": {
#         "stationId": "0840CBFEFFE70FFE",
#         "name": "Ansermetplatz",
#         "dateObserved": "2024-05-13T00:12:15Z",
#         "temperature": 14.089036,
#         "relativeHumidity": 86.31518
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48222,
#           46.95867
#         ]
#       },
#       "properties": {
#         "stationId": "460551FEFF6E959E",
#         "name": "Ostermundigen Poststrasse 2",
#         "dateObserved": "2024-05-13T00:12:14Z",
#         "temperature": 14.676509,
#         "relativeHumidity": 79.694664
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45656,
#           46.93798
#         ]
#       },
#       "properties": {
#         "stationId": "D03FCBFEFFE70FFE",
#         "name": "D\u00e4hlh\u00f6lzliwald",
#         "dateObserved": "2024-05-13T00:12:04Z",
#         "temperature": 13.469521,
#         "relativeHumidity": 90.25773
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.480363,
#           46.957783
#         ]
#       },
#       "properties": {
#         "stationId": "0B0551FEFF6E959E",
#         "name": "Ostermundigen Schermenweg",
#         "dateObserved": "2024-05-13T00:12:01Z",
#         "temperature": 15.111773,
#         "relativeHumidity": 77.564125
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.48719,
#           46.95309
#         ]
#       },
#       "properties": {
#         "stationId": "1D40CBFEFFE70FFE",
#         "name": "Ostermundigen L\u00f6tschenstrasse 13",
#         "dateObserved": "2024-05-13T00:11:46Z",
#         "temperature": 15.197223,
#         "relativeHumidity": 75.736855
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.481124,
#           46.926167
#         ]
#       },
#       "properties": {
#         "stationId": "61E350FEFF6E959E",
#         "name": "Muri Bl\u00fcmlisalpstrasse",
#         "dateObserved": "2024-05-13T00:11:45Z",
#         "temperature": 14.735256,
#         "relativeHumidity": 72.68314
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46442,
#           46.94469
#         ]
#       },
#       "properties": {
#         "stationId": "090551FEFF6E959E",
#         "name": "Egelsee",
#         "dateObserved": "2024-05-13T00:11:43Z",
#         "temperature": 15.058366,
#         "relativeHumidity": 77.16548
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.40633,
#           46.94333
#         ]
#       },
#       "properties": {
#         "stationId": "2F40CBFEFFE70FFE",
#         "name": "Europaplatz 2",
#         "dateObserved": "2024-05-13T00:11:41Z",
#         "temperature": 14.238575,
#         "relativeHumidity": 82.19905
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.490017,
#           46.980637
#         ]
#       },
#       "properties": {
#         "stationId": "C0C450FEFF6E959E",
#         "name": "Ittigen Gantrischweg 1 Laterne",
#         "dateObserved": "2024-05-13T00:11:41Z",
#         "temperature": 14.281301,
#         "relativeHumidity": 74.61341
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45351,
#           46.9481
#         ]
#       },
#       "properties": {
#         "stationId": "E4C450FEFF6E959E",
#         "name": "Gerechtigkeitsgasse",
#         "dateObserved": "2024-05-13T00:11:40Z",
#         "temperature": 15.918212,
#         "relativeHumidity": 72.57824
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.45824,
#           46.94059
#         ]
#       },
#       "properties": {
#         "stationId": "0A40CBFEFFE70FFE",
#         "name": "Thunplatz",
#         "dateObserved": "2024-05-13T00:11:31Z",
#         "temperature": 14.489586,
#         "relativeHumidity": 80.539635
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.498633,
#           46.892506
#         ]
#       },
#       "properties": {
#         "stationId": "30E450FEFF6E959E",
#         "name": "Belp Zentrum Laterne",
#         "dateObserved": "2024-05-13T00:11:26Z",
#         "temperature": 15.613794,
#         "relativeHumidity": 68.60136
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.471829,
#           46.94506
#         ]
#       },
#       "properties": {
#         "stationId": "B9C450FEFF6E959E",
#         "name": "Bern-Ostring Freudenbergplatz Laterne",
#         "dateObserved": "2024-05-13T00:11:24Z",
#         "temperature": 15.41352,
#         "relativeHumidity": 69.74387
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.43541,
#           46.95789
#         ]
#       },
#       "properties": {
#         "stationId": "CD3FCBFEFFE70FFE",
#         "name": "Hintere L\u00e4nggasse",
#         "dateObserved": "2024-05-13T00:11:17Z",
#         "temperature": 15.01297,
#         "relativeHumidity": 76.09544
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.44248,
#           46.90961
#         ]
#       },
#       "properties": {
#         "stationId": "4B40CBFEFFE70FFE",
#         "name": "K\u00f6niztal",
#         "dateObserved": "2024-05-13T00:11:09Z",
#         "temperature": 12.542916,
#         "relativeHumidity": 89.09804
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.46747,
#           46.9645
#         ]
#       },
#       "properties": {
#         "stationId": "E4EA50FEFF6E959E",
#         "name": "Bern Wankdorfplatz Laterne",
#         "dateObserved": "2024-05-13T00:11:09Z",
#         "temperature": 15.432212,
#         "relativeHumidity": 70.007095
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.415169,
#           46.90915
#         ]
#       },
#       "properties": {
#         "stationId": "8CDE50FEFF6E959E",
#         "name": "K\u00f6niz Schliern Laterne",
#         "dateObserved": "2024-05-13T00:08:41Z",
#         "temperature": 13.854048,
#         "relativeHumidity": 72.845276
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.5102544,
#           47.01997
#         ]
#       },
#       "properties": {
#         "stationId": "2940CBFEFFE70FFE",
#         "name": "Urtenen-Sch\u00f6nb\u00fchl (3322)",
#         "dateObserved": "2024-05-13T00:06:20Z",
#         "temperature": 16.278706,
#         "relativeHumidity": 72.52865
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           7.41466,
#           46.92327
#         ]
#       },
#       "properties": {
#         "stationId": "FCE350FEFF6E959E",
#         "name": "K\u00f6niz Bl\u00e4uacker Kandelaber auf Platz  ",
#         "dateObserved": "2024-05-13T00:06:06Z",
#         "temperature": 13.54429,
#         "relativeHumidity": 79.5478
#       }
#     }
#   ]
# }

# %% [markdown]
# Laden der Daten als GeoPandas Dataframe macht das ganze noch einfacher:

# %%
stations = gpd.read_file(response.text)

# Display stations DataFrame
stations

# %% [markdown]
# ### Schritt 3: Darstellen auf einer Karte
#
# Zuerst zeigen wir eine Karte an, die alle Messstationen abdeckt:

# %%
# Create a base map
map1 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=10)

# Display map
map1

# %% [markdown]
# Jetzt zeichnen wir die Messstationen ein:

# %%
# Create a base map
map2 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=10)

# Iterate through each station in the GeoPandas DataFrame
for idx, station in stations.iterrows():
    # Create a circle marker for each station and add it to the map
    folium.CircleMarker(
        # Location of the marker in lat and lon
        location=(station.geometry.y, station.geometry.x),
        # Styling the marker
        radius=5,
        color="black",  # Border color
        weight=0.5,  # Border width
        fill=True,
        fill_color="black",
        fill_opacity=1, # 1 means 100% opaque
        # Add a tooltip with station name
        tooltip=f"{station['name']}",
    # Add the marker to the map
    ).add_to(map2)

map2

# %% [markdown]
# Und zum Schluss können wir den Messpunkten eine von der aktuellen Temperatur abhängige Farbe geben und auch Tooltips hinzufügen:

# %%
# Create a base map
map3 = folium.Map(location=[stations.geometry.y.mean(), stations.geometry.x.mean()], zoom_start=13)#, tiles="CartoDB positron")

# Most popular colormaps are sequential, meaning that they have a start and end color
# Define a function to reverse a colormap
def reversed_colormap(existing):
    return branca.colormap.LinearColormap(
        colors=list(reversed(existing.colors)),
        vmin=existing.vmin, vmax=existing.vmax
    )

def formatToolTip(stationName, temperature, humidity):
    return f"{stationName}: {temperature:.2f}°C, {humidity:.2f}%"

def formatToolTip2(stationName, temperature, humidity):
    return f"<h4>{stationName}</h4>Temperatur: {temperature:.2f}°C<br/>Luftfeuchtigkeit: {humidity:.2f}%"


# Create a colormap for a temperature range of 10-37°C
# Choose an appropriate colormap (Spectral_11) and reverse it so that it goes from blue (cold) to red (hot)
colormap = reversed_colormap(branca.colormap.linear.Spectral_11)
# Scale the colormap to the temperature range and discretize it into 9 steps for better visibility
colormap = colormap.scale(10, 37).to_step(9)
# Add a caption to the colormap
colormap.caption = "Temperature (°C)"
# Add colormap to the map
colormap.add_to(map3)

# Iterate through each station in the GeoPandas DataFrame
for idx, station in stations.iterrows():
    # Create a circle marker for each station and add it to the map
    folium.CircleMarker(
        # Location of the marker in lon and lat
        location=(station.geometry.y, station.geometry.x),
        # Styling the marker
        radius=5,
        color="black",  # Border color
        weight=0.5,  # Border width
        fill=True,
        # Set the fill color to the colormap value corresponding to the station temperature
        fill_color=colormap(station['temperature']),
        fill_opacity=1, # 1 means 100% opaque
        # Add a tooltip with station name and temperature
        tooltip=formatToolTip2(station['name'], station['temperature'], station['relativeHumidity'])
    # Add the marker to the map
    ).add_to(map3)

# Display map
map3

# %% [markdown]
# ## Teil 2 - Zeitlichen Messdatenverlauf darstellen

# %% [markdown]
# ### Schritt 1: Daten zu einer Messstation laden
#
# Z.B. am Bundesplatz:

# %%
# Based on a station name, get the respective stationId from the DataFrame
stationId = stations[stations["name"] == "Bundesplatz"].stationId.values[0]
# Define the URL including the stationId argument
url = f"https://smart-urban-heat-map.ch/api/1.0/timeseries?stationId={stationId}"

# Define the headers to request CSV data as a python dictionary
headers = {
    "Accept": "text/csv"
}

# Make the GET request with the headers
response = requests.get(url, headers=headers)

# Get the timeseries into a data frame
timeseries = pd.read_csv(io.StringIO(response.text), delimiter=";")

timeseries

# %% [markdown]
# ### Schritt 2: Daten grafisch darstellen

# %%
# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
ax = timeseries.plot(x='dateObserved', y='temperature', figsize=(10,6), marker=None, linestyle='-')
# The ax object is a matplotlib axis object which we can use to further customize the plot

# Add a title
ax.set_title('Bundesplatz')

# Add labels for the x and y axes
ax.set_xlabel('Zeit')
ax.set_ylabel('Temperatur (°C)')

# Shift every second x-label for better readability
for i, label in enumerate(ax.get_xticklabels()):
    if i % 2 == 0:  # Check if it's an odd tick
        label.set_y(-0.04)

# %% [markdown]
# ### Schritt 3: Daten von mehreren Stationen anzeigen
# Zuerst legen wir den Zeitraum fest:

# %%
startTime = "2023-09-28T00:00:00Z" # 28.09.23 00:00 ; Z means UTC time
endTime = "2023-09-30T23:00:00Z" # 31.09.23 23:00

# %% [markdown]
# Jetzt lesen wir die Daten:

# %%
import matplotlib.pyplot as plt

# Define function to read the data for a specific statio and a specific time range.
# Returns the data as a Pandas dataframe
def getData(stationName, startTime, endTime):
    #Define the headers to request CSV data as a python dictionary
    headers = {
        "Accept": "text/csv"
    }

    # Read the data
    stationId = stations[stations["name"] == stationName].stationId.values[0]
    # Define the URL including the stationId argument
    url = f"https://smart-urban-heat-map.ch/api/1.0/timeseries?stationId={stationId}&timeFrom={startTime}&timeTo={endTime}"

    # Make the GET request with the headers
    response = requests.get(url, headers=headers)
    return pd.read_csv(io.StringIO(response.text), delimiter=";")

# Read the data for the 3 stations:
timeseries1 = getData("Bundesplatz", startTime, endTime)
timeseries2 = getData("Marktplatz Lyss", startTime, endTime)
timeseries3 = getData("Sigriswil", startTime, endTime)

# Now plot the data
plt.figure(figsize=(10, 6))


# Use the DataFrame plot function to plot the temperature time series as a line plot with markers
timeseries1.plot(x='dateObserved', y='temperature', label="Bundesplatz", marker=None, color='blue', linestyle='-', ax=plt.gca())
timeseries2.plot(x='dateObserved', y='temperature', label="Marktplatz Lyss", marker=None, color='green', linestyle='-', ax=plt.gca())
timeseries3.plot(x='dateObserved', y='temperature', label="Sigriswil", marker=None, color='red', linestyle='-', ax=plt.gca())

plt.title('Temperaturverlauf')
plt.xlabel('Zeit')
plt.ylabel('Temperatur (°C)')
